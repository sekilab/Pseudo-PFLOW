# %%
import os
import pandas as pd
import numpy as np
import random
import logging

pd.set_option('display.max_columns', None)

# %%
logging.basicConfig(filename='household_data_mismatches.log', level=logging.WARNING, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def process_census_data(df):
    """
    Process the census data to create a lookup for working probabilities based on gender and prefecture.

    Parameters:
    - df: DataFrame containing the census data.

    Returns:
    - A dictionary with (gender, prefecture) tuples as keys and working probabilities as values.
    """
    df['pref'] = df['地域名'].str.split("-").str[0].str[:2]
    df['gender'] = df['男女'].str.split("_").str[0]
    return df.set_index(['gender', 'pref'])['労働力率'].to_dict()

def transform_pref_code(city_code):
    """
    Transform the city code to a prefecture code.

    Parameters:
    - city_code: The city code as an integer.

    Returns:
    - The prefecture code as a string.
    """
    city_code_str = str(city_code)
    return city_code_str[:2] if len(city_code_str) == 5 else '0'+city_code_str[0]

def get_occupation(age, gender, prefecture, working_probability_lookup):
    """
    Determine the working status based on age, gender, and prefecture.

    Parameters:
    - age: Age of the individual.
    - gender: Gender of the individual.
    - prefecture: Prefecture code of the individual's location.
    - working_probability_lookup: A dictionary for looking up working probabilities.

    Returns:
    - An occupation code.
    """
    if age <= 4:
        return 10
    elif age <= 6:
        return 11
    elif age <= 12:
        return 12
    elif age <= 15:
        return 13
    elif age <= 18:
        return 14
    elif age <= 64:
        key = (str(int(gender)), str(prefecture))
        working_probability = working_probability_lookup.get(key, 0.5) / 100.0
        if working_probability == 0.5:
            print(key)
        return np.random.choice([23, 21], p=[working_probability, 1 - working_probability])
    else:
        return 23

def create_individual(base_info, age, gender, pref_code, person_counter, working_probability_lookup):
    """
    Create an individual's information based on the given parameters.

    Parameters:
    - base_info: A dictionary containing the base information shared by all individuals in the household.
    - age: Age of the individual.
    - gender: Gender of the individual.
    - pref_code: Prefecture code of the individual's location.
    - person_counter: A counter for assigning a unique person_id within the household.
    - working_probability_lookup: A dictionary for looking up working probabilities.

    Returns:
    - A dictionary with the individual's information.
    """
    individual = base_info.copy()
    individual['person_id'] = f'{person_counter}'
    age = age + random.randint(0, 4)
    individual['age'] = age
    individual['gender'] = gender
    individual['occupation'] = get_occupation(age, gender, pref_code, working_probability_lookup)
    
    return individual

def generate_individuals(household_data, city_code, working_probability_lookup, person_counter):
    """
    Generate individual records from household data.

    Parameters:
    - household_data: DataFrame containing household data.
    - city_code: City code for the household location.
    - working_probability_lookup: A dictionary for looking up working probabilities.

    Returns:
    - A DataFrame with individual records.
    """
    individuals = []

    for _, row in household_data.iterrows():
        base_info = {
            'household_id': f'{city_code}_{int(row["gid"])}',
            'family_type': row['family_group_code'],
            'city_code': row['city_code'],
            'lon': row['lon'],
            'lat': row['lat'],
        }
        pref_code = transform_pref_code(city_code)

        # Process householder, spouse, parents, children, and others
        for role in ['hh', 'spouse', 'parent_male', 'parent_female']:
            age_col = f'age_code_{role}'
            gender_col = f'gender_code_{role}'

            if pd.notna(row[age_col]) and pd.notna(row[gender_col]):
                individual = create_individual(base_info, row[age_col], row[gender_col], pref_code, person_counter, working_probability_lookup)
                individuals.append(individual)
                person_counter += 1

        # Process children and other members if applicable
        for member_type, col_step in [('child', 4), ('others', 5)]:
            start_index = household_data.columns.get_loc(f"gender_code_1st_{member_type}")
            end_index = household_data.columns.get_loc(f"{member_type}_counts_15th_grandchild") if member_type == 'child' else household_data.columns.get_loc(f"generation_flag_15th_{member_type}")

            for i in range(start_index, end_index, col_step):
                if i + 2 >= len(household_data.columns):  # Ensure we don't go beyond the DataFrame's columns
                    break

                gender, age = row.iloc[i], row.iloc[i + 1]
                if pd.notna(gender) and pd.notna(age):
                    individual = create_individual(base_info, age, gender, pref_code, person_counter, working_probability_lookup)
                    individuals.append(individual)
                    person_counter += 1

        # Check if the number of generated individuals matches the expected number
        if person_counter - 1 != int(row['n_household_member']):
            logging.warning(f"Mismatch in household {row['gid']} in city {city_code}: Expected {row['n_household_member']}, got {person_counter - 1}")

    return pd.DataFrame(individuals)

# %%
household_path = '/mnt/large/data/household_estimation_data_2020/世帯推計データ(加工済み)_202401/sisetu_plus_all/'
pseudo_pop_path = '/mnt/large/data/PseudoPFLOW/ver2.0/Population/'

# Load census data for working probabilities
census_data_path = '/mnt/large/data/PseudoPFLOW/Processing/2020NationalCensusLabor.csv'
census_data = pd.read_csv(census_data_path)
working_probability_lookup = process_census_data(census_data)

dtype_conversion = {
    'household_id': 'str',
    'family_type': 'Int64',
    'city_code': 'Int64',
    'age': 'Int64', 
    'gender': 'Int64'
}

person_counter = 1

for subdir, dirs, files in os.walk(household_path):
    dirs.sort()  # Sort directories in-place
    files.sort()  # Sort files in-place
    
    pref_folder = os.path.basename(subdir)

    pseudo_dir_path = os.path.join(pseudo_pop_path, pref_folder)

    # Check if the directory exists, if not, create it
    if not os.path.exists(pseudo_dir_path):
        os.makedirs(pseudo_dir_path)
        print(f"Created directory: {pseudo_dir_path}")

    for file in files:
        # Construct the full file path
        print(file, person_counter)
        city_code = file.split('_')[0]
        household_data_path = os.path.join(subdir, file)
        household_data = pd.read_csv(household_data_path)
        
        # Generate individual records
        try:
            individuals_df = generate_individuals(household_data, city_code, working_probability_lookup, person_counter)
            individuals_df = individuals_df.astype(dtype_conversion)
            individuals_df.to_csv(pseudo_dir_path + '/person_' + city_code + '.csv', index=False)
        except KeyError as e:
            print(f"Error: {e}. This column name does not exist in individuals_df DataFrame for file {file}.")
# Out:
# 01101_household_estimation_data_2020.csv 1
# 01102_household_estimation_data_2020.csv 1
# 01103_household_estimation_data_2020.csv 1
# 01104_household_estimation_data_2020.csv 1
# 01105_household_estimation_data_2020.csv 1
# 01106_household_estimation_data_2020.csv 1
# 01107_household_estimation_data_2020.csv 1
# 01108_household_estimation_data_2020.csv 1
# 01109_household_estimation_data_2020.csv 1
# 01110_household_estimation_data_2020.csv 1
# 01202_household_estimation_data_2020.csv 1
# 01203_household_estimation_data_2020.csv 1
# 01204_household_estimation_data_2020.csv 1
# 01205_household_estimation_data_2020.csv 1
# 01206_household_estimation_data_2020.csv 1
# 01207_household_estimation_data_2020.csv 1
# 01208_household_estimation_data_2020.csv 1
# 01209_household_estimation_data_2020.csv 1
# 01210_household_estimation_data_2020.csv 1
# 01211_household_estimation_data_2020.csv 1
# 01212_household_estimation_data_2020.csv 1
# 01213_household_estimation_data_2020.csv 1
# 01214_household_estimation_data_2020.csv 1
# 01215_household_estimation_data_2020.csv 1
# 01216_household_estimation_data_2020.csv 1
# 01217_household_estimation_data_2020.csv 1
# 01218_household_estimation_data_2020.csv 1
# 01219_household_estimation_data_2020.csv 1
# 01220_household_estimation_data_2020.csv 1
# 01221_household_estimation_data_2020.csv 1
# 01222_household_estimation_data_2020.csv 1
# 01223_household_estimation_data_2020.csv 1
# 01224_household_estimation_data_2020.csv 1
# 01225_household_estimation_data_2020.csv 1
# 01226_household_estimation_data_2020.csv 1
# 01227_household_estimation_data_2020.csv 1
# 01228_household_estimation_data_2020.csv 1
# 01229_household_estimation_data_2020.csv 1
# 01230_household_estimation_data_2020.csv 1
# 01231_household_estimation_data_2020.csv 1
# 01233_household_estimation_data_2020.csv 1
# 01234_household_estimation_data_2020.csv 1
# 01235_household_estimation_data_2020.csv 1
# 01236_household_estimation_data_2020.csv 1
# 01303_household_estimation_data_2020.csv 1
# 01304_household_estimation_data_2020.csv 1
# 01331_household_estimation_data_2020.csv 1
# 01332_household_estimation_data_2020.csv 1
# 01333_household_estimation_data_2020.csv 1
# 01334_household_estimation_data_2020.csv 1
# 01337_household_estimation_data_2020.csv 1
# 01343_household_estimation_data_2020.csv 1
# 01345_household_estimation_data_2020.csv 1
# 01346_household_estimation_data_2020.csv 1
# 01347_household_estimation_data_2020.csv 1
# 01361_household_estimation_data_2020.csv 1
# 01362_household_estimation_data_2020.csv 1
# 01363_household_estimation_data_2020.csv 1
# 01364_household_estimation_data_2020.csv 1
# 01367_household_estimation_data_2020.csv 1
# 01370_household_estimation_data_2020.csv 1
# 01371_household_estimation_data_2020.csv 1
# 01391_household_estimation_data_2020.csv 1
# 01392_household_estimation_data_2020.csv 1
# 01393_household_estimation_data_2020.csv 1
# 01394_household_estimation_data_2020.csv 1
# 01395_household_estimation_data_2020.csv 1
# 01396_household_estimation_data_2020.csv 1
# 01397_household_estimation_data_2020.csv 1
# 01398_household_estimation_data_2020.csv 1
# 01399_household_estimation_data_2020.csv 1
# 01400_household_estimation_data_2020.csv 1
# 01401_household_estimation_data_2020.csv 1
# 01402_household_estimation_data_2020.csv 1
# 01403_household_estimation_data_2020.csv 1
# 01404_household_estimation_data_2020.csv 1
# Error: "Only a column name can be used for the key in a dtype mappings argument. 'household_id' not found in columns.". This column name does not exist in individuals_df DataFrame for file 01404_household_estimation_data_2020.csv.
# 01405_household_estimation_data_2020.csv 1
# 01406_household_estimation_data_2020.csv 1
# 01407_household_estimation_data_2020.csv 1
# 01408_household_estimation_data_2020.csv 1
# 01409_household_estimation_data_2020.csv 1
# 01423_household_estimation_data_2020.csv 1
# 01424_household_estimation_data_2020.csv 1
# 01425_household_estimation_data_2020.csv 1
# 01427_household_estimation_data_2020.csv 1
# 01428_household_estimation_data_2020.csv 1
# 01429_household_estimation_data_2020.csv 1
# 01430_household_estimation_data_2020.csv 1
# 01431_household_estimation_data_2020.csv 1
# 01432_household_estimation_data_2020.csv 1
# 01433_household_estimation_data_2020.csv 1
# 01434_household_estimation_data_2020.csv 1
# 01436_household_estimation_data_2020.csv 1
# 01437_household_estimation_data_2020.csv 1
# 01438_household_estimation_data_2020.csv 1
# 01452_household_estimation_data_2020.csv 1
# 01453_household_estimation_data_2020.csv 1
# 01454_household_estimation_data_2020.csv 1
# 01455_household_estimation_data_2020.csv 1
# 01456_household_estimation_data_2020.csv 1
# 01457_household_estimation_data_2020.csv 1
# 01458_household_estimation_data_2020.csv 1
# 01459_household_estimation_data_2020.csv 1
# 01460_household_estimation_data_2020.csv 1
# 01461_household_estimation_data_2020.csv 1
# 01462_household_estimation_data_2020.csv 1
# 01463_household_estimation_data_2020.csv 1
# 01464_household_estimation_data_2020.csv 1
# 01465_household_estimation_data_2020.csv 1
# 01468_household_estimation_data_2020.csv 1
# 01469_household_estimation_data_2020.csv 1
# 01470_household_estimation_data_2020.csv 1
# 01471_household_estimation_data_2020.csv 1
# 01472_household_estimation_data_2020.csv 1
# 01481_household_estimation_data_2020.csv 1
# 01482_household_estimation_data_2020.csv 1
# 01483_household_estimation_data_2020.csv 1
# 01484_household_estimation_data_2020.csv 1
# 01485_household_estimation_data_2020.csv 1
# 01486_household_estimation_data_2020.csv 1
# 01487_household_estimation_data_2020.csv 1
# 01511_household_estimation_data_2020.csv 1
# 01512_household_estimation_data_2020.csv 1
# 01513_household_estimation_data_2020.csv 1
# 01514_household_estimation_data_2020.csv 1
# 01516_household_estimation_data_2020.csv 1
# 01517_household_estimation_data_2020.csv 1
# 01518_household_estimation_data_2020.csv 1
# 01519_household_estimation_data_2020.csv 1
# 01520_household_estimation_data_2020.csv 1
# 01543_household_estimation_data_2020.csv 1
# 01544_household_estimation_data_2020.csv 1
# 01545_household_estimation_data_2020.csv 1
# 01546_household_estimation_data_2020.csv 1
# 01547_household_estimation_data_2020.csv 1
# 01549_household_estimation_data_2020.csv 1
# 01550_household_estimation_data_2020.csv 1
# 01552_household_estimation_data_2020.csv 1
# 01555_household_estimation_data_2020.csv 1
# 01559_household_estimation_data_2020.csv 1
# 01560_household_estimation_data_2020.csv 1
# 01561_household_estimation_data_2020.csv 1
# 01562_household_estimation_data_2020.csv 1
# 01563_household_estimation_data_2020.csv 1
# 01564_household_estimation_data_2020.csv 1
# 01571_household_estimation_data_2020.csv 1
# 01575_household_estimation_data_2020.csv 1
# 01578_household_estimation_data_2020.csv 1
# 01581_household_estimation_data_2020.csv 1
# 01584_household_estimation_data_2020.csv 1
# 01585_household_estimation_data_2020.csv 1
# 01586_household_estimation_data_2020.csv 1
# 01601_household_estimation_data_2020.csv 1
# 01602_household_estimation_data_2020.csv 1
# 01604_household_estimation_data_2020.csv 1
# 01607_household_estimation_data_2020.csv 1
# 01608_household_estimation_data_2020.csv 1
# 01609_household_estimation_data_2020.csv 1
# 01610_household_estimation_data_2020.csv 1
# 01631_household_estimation_data_2020.csv 1
# 01632_household_estimation_data_2020.csv 1
# 01633_household_estimation_data_2020.csv 1
# 01634_household_estimation_data_2020.csv 1
# 01635_household_estimation_data_2020.csv 1
# 01636_household_estimation_data_2020.csv 1
# 01637_household_estimation_data_2020.csv 1
# 01638_household_estimation_data_2020.csv 1
# 01639_household_estimation_data_2020.csv 1
# 01641_household_estimation_data_2020.csv 1
# 01642_household_estimation_data_2020.csv 1
# 01643_household_estimation_data_2020.csv 1
# 01644_household_estimation_data_2020.csv 1
# 01645_household_estimation_data_2020.csv 1
# 01646_household_estimation_data_2020.csv 1
# 01647_household_estimation_data_2020.csv 1
# 01648_household_estimation_data_2020.csv 1
# 01649_household_estimation_data_2020.csv 1
# 01661_household_estimation_data_2020.csv 1
# 01662_household_estimation_data_2020.csv 1
# 01663_household_estimation_data_2020.csv 1
# 01664_household_estimation_data_2020.csv 1
# 01665_household_estimation_data_2020.csv 1
# 01667_household_estimation_data_2020.csv 1
# 01668_household_estimation_data_2020.csv 1
# 01691_household_estimation_data_2020.csv 1
# 01692_household_estimation_data_2020.csv 1
# 01693_household_estimation_data_2020.csv 1
# 01694_household_estimation_data_2020.csv 1
# 02201_household_estimation_data_2020.csv 1
# 02202_household_estimation_data_2020.csv 1
# 02203_household_estimation_data_2020.csv 1
# 02204_household_estimation_data_2020.csv 1
# 02205_household_estimation_data_2020.csv 1
# 02206_household_estimation_data_2020.csv 1
# 02207_household_estimation_data_2020.csv 1
# 02208_household_estimation_data_2020.csv 1
# 02209_household_estimation_data_2020.csv 1
# 02210_household_estimation_data_2020.csv 1
# 02301_household_estimation_data_2020.csv 1
# 02303_household_estimation_data_2020.csv 1
# 02304_household_estimation_data_2020.csv 1
# 02307_household_estimation_data_2020.csv 1
# 02321_household_estimation_data_2020.csv 1
# 02323_household_estimation_data_2020.csv 1
# 02343_household_estimation_data_2020.csv 1
# 02361_household_estimation_data_2020.csv 1
# 02362_household_estimation_data_2020.csv 1
# 02367_household_estimation_data_2020.csv 1
# 02381_household_estimation_data_2020.csv 1
# 02384_household_estimation_data_2020.csv 1
# 02387_household_estimation_data_2020.csv 1
# 02401_household_estimation_data_2020.csv 1
# 02402_household_estimation_data_2020.csv 1
# 02405_household_estimation_data_2020.csv 1
# 02406_household_estimation_data_2020.csv 1
# 02408_household_estimation_data_2020.csv 1
# 02411_household_estimation_data_2020.csv 1
# 02412_household_estimation_data_2020.csv 1
# 02423_household_estimation_data_2020.csv 1
# 02424_household_estimation_data_2020.csv 1
# 02425_household_estimation_data_2020.csv 1
# 02426_household_estimation_data_2020.csv 1
# 02441_household_estimation_data_2020.csv 1
# 02442_household_estimation_data_2020.csv 1
# 02443_household_estimation_data_2020.csv 1
# 02445_household_estimation_data_2020.csv 1
# 02446_household_estimation_data_2020.csv 1
# 02450_household_estimation_data_2020.csv 1
# 03201_household_estimation_data_2020.csv 1
# 03202_household_estimation_data_2020.csv 1
# 03203_household_estimation_data_2020.csv 1
# 03205_household_estimation_data_2020.csv 1
# 03206_household_estimation_data_2020.csv 1
# 03207_household_estimation_data_2020.csv 1
# 03208_household_estimation_data_2020.csv 1
# 03209_household_estimation_data_2020.csv 1
# 03210_household_estimation_data_2020.csv 1
# 03211_household_estimation_data_2020.csv 1
# 03213_household_estimation_data_2020.csv 1
# 03214_household_estimation_data_2020.csv 1
# 03215_household_estimation_data_2020.csv 1
# 03216_household_estimation_data_2020.csv 1
# 03301_household_estimation_data_2020.csv 1
# 03302_household_estimation_data_2020.csv 1
# 03303_household_estimation_data_2020.csv 1
# 03321_household_estimation_data_2020.csv 1
# 03322_household_estimation_data_2020.csv 1
# 03366_household_estimation_data_2020.csv 1
# 03381_household_estimation_data_2020.csv 1
# 03402_household_estimation_data_2020.csv 1
# 03441_household_estimation_data_2020.csv 1
# 03461_household_estimation_data_2020.csv 1
# 03482_household_estimation_data_2020.csv 1
# 03483_household_estimation_data_2020.csv 1
# 03484_household_estimation_data_2020.csv 1
# 03485_household_estimation_data_2020.csv 1
# 03501_household_estimation_data_2020.csv 1
# 03503_household_estimation_data_2020.csv 1
# 03506_household_estimation_data_2020.csv 1
# 03507_household_estimation_data_2020.csv 1
# 03524_household_estimation_data_2020.csv 1
# 04101_household_estimation_data_2020.csv 1
# 04102_household_estimation_data_2020.csv 1
# 04103_household_estimation_data_2020.csv 1
# 04104_household_estimation_data_2020.csv 1
# 04105_household_estimation_data_2020.csv 1
# 04202_household_estimation_data_2020.csv 1
# 04203_household_estimation_data_2020.csv 1
# 04205_household_estimation_data_2020.csv 1
# 04206_household_estimation_data_2020.csv 1
# 04207_household_estimation_data_2020.csv 1
# 04208_household_estimation_data_2020.csv 1
# 04209_household_estimation_data_2020.csv 1
# 04211_household_estimation_data_2020.csv 1
# 04212_household_estimation_data_2020.csv 1
# 04213_household_estimation_data_2020.csv 1
# 04214_household_estimation_data_2020.csv 1
# 04215_household_estimation_data_2020.csv 1
# 04216_household_estimation_data_2020.csv 1
# Error: "Only a column name can be used for the key in a dtype mappings argument. 'household_id' not found in columns.". This column name does not exist in individuals_df DataFrame for file 04216_household_estimation_data_2020.csv.
# 04301_household_estimation_data_2020.csv 1
# 04302_household_estimation_data_2020.csv 1
# 04321_household_estimation_data_2020.csv 1
# 04322_household_estimation_data_2020.csv 1
# 04323_household_estimation_data_2020.csv 1
# 04324_household_estimation_data_2020.csv 1
# 04341_household_estimation_data_2020.csv 1
# 04361_household_estimation_data_2020.csv 1
# 04362_household_estimation_data_2020.csv 1
# 04401_household_estimation_data_2020.csv 1
# 04404_household_estimation_data_2020.csv 1
# 04406_household_estimation_data_2020.csv 1
# 04421_household_estimation_data_2020.csv 1
# 04422_household_estimation_data_2020.csv 1
# 04424_household_estimation_data_2020.csv 1
# 04444_household_estimation_data_2020.csv 1
# 04445_household_estimation_data_2020.csv 1
# 04501_household_estimation_data_2020.csv 1
# 04505_household_estimation_data_2020.csv 1
# 04581_household_estimation_data_2020.csv 1
# 04606_household_estimation_data_2020.csv 1
# 05201_household_estimation_data_2020.csv 1
# 05202_household_estimation_data_2020.csv 1
# 05203_household_estimation_data_2020.csv 1
# 05204_household_estimation_data_2020.csv 1
# 05206_household_estimation_data_2020.csv 1
# 05207_household_estimation_data_2020.csv 1
# 05209_household_estimation_data_2020.csv 1
# 05210_household_estimation_data_2020.csv 1
# 05211_household_estimation_data_2020.csv 1
# 05212_household_estimation_data_2020.csv 1
# 05213_household_estimation_data_2020.csv 1
# 05214_household_estimation_data_2020.csv 1
# 05215_household_estimation_data_2020.csv 1
# 05303_household_estimation_data_2020.csv 1
# 05327_household_estimation_data_2020.csv 1
# 05346_household_estimation_data_2020.csv 1
# 05348_household_estimation_data_2020.csv 1
# 05349_household_estimation_data_2020.csv 1
# 05361_household_estimation_data_2020.csv 1
# 05363_household_estimation_data_2020.csv 1
# 05366_household_estimation_data_2020.csv 1
# 05368_household_estimation_data_2020.csv 1
# 05434_household_estimation_data_2020.csv 1
# 05463_household_estimation_data_2020.csv 1
# 05464_household_estimation_data_2020.csv 1
# 06201_household_estimation_data_2020.csv 1
# 06202_household_estimation_data_2020.csv 1
# 06203_household_estimation_data_2020.csv 1
# 06204_household_estimation_data_2020.csv 1
# 06205_household_estimation_data_2020.csv 1
# 06206_household_estimation_data_2020.csv 1
# 06207_household_estimation_data_2020.csv 1
# 06208_household_estimation_data_2020.csv 1
# 06209_household_estimation_data_2020.csv 1
# 06210_household_estimation_data_2020.csv 1
# 06211_household_estimation_data_2020.csv 1
# 06212_household_estimation_data_2020.csv 1
# 06213_household_estimation_data_2020.csv 1
# 06301_household_estimation_data_2020.csv 1
# 06302_household_estimation_data_2020.csv 1
# 06321_household_estimation_data_2020.csv 1
# 06322_household_estimation_data_2020.csv 1
# 06323_household_estimation_data_2020.csv 1
# 06324_household_estimation_data_2020.csv 1
# 06341_household_estimation_data_2020.csv 1
# 06361_household_estimation_data_2020.csv 1
# 06362_household_estimation_data_2020.csv 1
# 06363_household_estimation_data_2020.csv 1
# 06364_household_estimation_data_2020.csv 1
# 06365_household_estimation_data_2020.csv 1
# 06366_household_estimation_data_2020.csv 1
# 06367_household_estimation_data_2020.csv 1
# 06381_household_estimation_data_2020.csv 1
# 06382_household_estimation_data_2020.csv 1
# 06401_household_estimation_data_2020.csv 1
# 06402_household_estimation_data_2020.csv 1
# 06403_household_estimation_data_2020.csv 1
# 06426_household_estimation_data_2020.csv 1
# 06428_household_estimation_data_2020.csv 1
# 06461_household_estimation_data_2020.csv 1
# 07201_household_estimation_data_2020.csv 1
# 07202_household_estimation_data_2020.csv 1
# 07203_household_estimation_data_2020.csv 1
# 07204_household_estimation_data_2020.csv 1
# 07205_household_estimation_data_2020.csv 1
# 07207_household_estimation_data_2020.csv 1
# 07208_household_estimation_data_2020.csv 1
# 07209_household_estimation_data_2020.csv 1
# 07210_household_estimation_data_2020.csv 1
# 07211_household_estimation_data_2020.csv 1
# 07212_household_estimation_data_2020.csv 1
# 07213_household_estimation_data_2020.csv 1
# 07214_household_estimation_data_2020.csv 1
# 07301_household_estimation_data_2020.csv 1
# 07303_household_estimation_data_2020.csv 1
# 07308_household_estimation_data_2020.csv 1
# 07322_household_estimation_data_2020.csv 1
# 07342_household_estimation_data_2020.csv 1
# 07344_household_estimation_data_2020.csv 1
# 07362_household_estimation_data_2020.csv 1
# 07364_household_estimation_data_2020.csv 1
# 07367_household_estimation_data_2020.csv 1
# 07368_household_estimation_data_2020.csv 1
# 07402_household_estimation_data_2020.csv 1
# 07405_household_estimation_data_2020.csv 1
# 07407_household_estimation_data_2020.csv 1
# 07408_household_estimation_data_2020.csv 1
# 07421_household_estimation_data_2020.csv 1
# 07422_household_estimation_data_2020.csv 1
# 07423_household_estimation_data_2020.csv 1
# 07444_household_estimation_data_2020.csv 1
# 07445_household_estimation_data_2020.csv 1
# 07446_household_estimation_data_2020.csv 1
# 07447_household_estimation_data_2020.csv 1
# 07461_household_estimation_data_2020.csv 1
# 07464_household_estimation_data_2020.csv 1
# 07465_household_estimation_data_2020.csv 1
# 07466_household_estimation_data_2020.csv 1
# 07481_household_estimation_data_2020.csv 1
# 07482_household_estimation_data_2020.csv 1
# 07483_household_estimation_data_2020.csv 1
# 07484_household_estimation_data_2020.csv 1
# 07501_household_estimation_data_2020.csv 1
# 07502_household_estimation_data_2020.csv 1
# 07503_household_estimation_data_2020.csv 1
# 07504_household_estimation_data_2020.csv 1
# 07505_household_estimation_data_2020.csv 1
# 07521_household_estimation_data_2020.csv 1
# 07522_household_estimation_data_2020.csv 1
# 07541_household_estimation_data_2020.csv 1
# 07542_household_estimation_data_2020.csv 1
# 07543_household_estimation_data_2020.csv 1
# 07544_household_estimation_data_2020.csv 1
# 07545_household_estimation_data_2020.csv 1
# 07546_household_estimation_data_2020.csv 1
# Error: "Only a column name can be used for the key in a dtype mappings argument. 'household_id' not found in columns.". This column name does not exist in individuals_df DataFrame for file 07546_household_estimation_data_2020.csv.
# 07547_household_estimation_data_2020.csv 1
# 07548_household_estimation_data_2020.csv 1
# 07561_household_estimation_data_2020.csv 1
# 07564_household_estimation_data_2020.csv 1
# 08201_household_estimation_data_2020.csv 1
# 08202_household_estimation_data_2020.csv 1
# 08203_household_estimation_data_2020.csv 1
# 08204_household_estimation_data_2020.csv 1
# 08205_household_estimation_data_2020.csv 1
# 08207_household_estimation_data_2020.csv 1
# 08208_household_estimation_data_2020.csv 1
# 08210_household_estimation_data_2020.csv 1
# 08211_household_estimation_data_2020.csv 1
# 08212_household_estimation_data_2020.csv 1
# 08214_household_estimation_data_2020.csv 1
# 08215_household_estimation_data_2020.csv 1
# 08216_household_estimation_data_2020.csv 1
# 08217_household_estimation_data_2020.csv 1
# 08219_household_estimation_data_2020.csv 1
# 08220_household_estimation_data_2020.csv 1
# 08221_household_estimation_data_2020.csv 1
# 08222_household_estimation_data_2020.csv 1
# 08223_household_estimation_data_2020.csv 1
# 08224_household_estimation_data_2020.csv 1
# 08225_household_estimation_data_2020.csv 1
# 08226_household_estimation_data_2020.csv 1
# 08227_household_estimation_data_2020.csv 1
# 08228_household_estimation_data_2020.csv 1
# 08229_household_estimation_data_2020.csv 1
# 08230_household_estimation_data_2020.csv 1
# 08231_household_estimation_data_2020.csv 1
# 08232_household_estimation_data_2020.csv 1
# 08233_household_estimation_data_2020.csv 1
# 08234_household_estimation_data_2020.csv 1
# 08235_household_estimation_data_2020.csv 1
# 08236_household_estimation_data_2020.csv 1
# 08302_household_estimation_data_2020.csv 1
# 08309_household_estimation_data_2020.csv 1
# 08310_household_estimation_data_2020.csv 1
# 08341_household_estimation_data_2020.csv 1
# 08364_household_estimation_data_2020.csv 1
# 08442_household_estimation_data_2020.csv 1
# 08443_household_estimation_data_2020.csv 1
# 08447_household_estimation_data_2020.csv 1
# 08521_household_estimation_data_2020.csv 1
# 08542_household_estimation_data_2020.csv 1
# 08546_household_estimation_data_2020.csv 1
# 08564_household_estimation_data_2020.csv 1
# 09201_household_estimation_data_2020.csv 1
# 09202_household_estimation_data_2020.csv 1
# 09203_household_estimation_data_2020.csv 1
# 09204_household_estimation_data_2020.csv 1
# 09205_household_estimation_data_2020.csv 1
# 09206_household_estimation_data_2020.csv 1
# 09208_household_estimation_data_2020.csv 1
# 09209_household_estimation_data_2020.csv 1
# 09210_household_estimation_data_2020.csv 1
# 09211_household_estimation_data_2020.csv 1
# 09213_household_estimation_data_2020.csv 1
# 09214_household_estimation_data_2020.csv 1
# 09215_household_estimation_data_2020.csv 1
# 09216_household_estimation_data_2020.csv 1
# 09301_household_estimation_data_2020.csv 1
# 09342_household_estimation_data_2020.csv 1
# 09343_household_estimation_data_2020.csv 1
# 09344_household_estimation_data_2020.csv 1
# 09345_household_estimation_data_2020.csv 1
# 09361_household_estimation_data_2020.csv 1
# 09364_household_estimation_data_2020.csv 1
# 09384_household_estimation_data_2020.csv 1
# 09386_household_estimation_data_2020.csv 1
# 09407_household_estimation_data_2020.csv 1
# 09411_household_estimation_data_2020.csv 1
# 10201_household_estimation_data_2020.csv 1
# 10202_household_estimation_data_2020.csv 1
# 10203_household_estimation_data_2020.csv 1
# 10204_household_estimation_data_2020.csv 1
# 10205_household_estimation_data_2020.csv 1
# 10206_household_estimation_data_2020.csv 1
# 10207_household_estimation_data_2020.csv 1
# 10208_household_estimation_data_2020.csv 1
# 10209_household_estimation_data_2020.csv 1
# 10210_household_estimation_data_2020.csv 1
# 10211_household_estimation_data_2020.csv 1
# 10212_household_estimation_data_2020.csv 1
# 10344_household_estimation_data_2020.csv 1
# 10345_household_estimation_data_2020.csv 1
# 10366_household_estimation_data_2020.csv 1
# 10367_household_estimation_data_2020.csv 1
# 10382_household_estimation_data_2020.csv 1
# 10383_household_estimation_data_2020.csv 1
# 10384_household_estimation_data_2020.csv 1
# 10421_household_estimation_data_2020.csv 1
# 10424_household_estimation_data_2020.csv 1
# 10425_household_estimation_data_2020.csv 1
# 10426_household_estimation_data_2020.csv 1
# 10428_household_estimation_data_2020.csv 1
# 10429_household_estimation_data_2020.csv 1
# 10443_household_estimation_data_2020.csv 1
# 10444_household_estimation_data_2020.csv 1
# 10448_household_estimation_data_2020.csv 1
# 10449_household_estimation_data_2020.csv 1
# 10464_household_estimation_data_2020.csv 1
# 10521_household_estimation_data_2020.csv 1
# 10522_household_estimation_data_2020.csv 1
# 10523_household_estimation_data_2020.csv 1
# 10524_household_estimation_data_2020.csv 1
# 10525_household_estimation_data_2020.csv 1
# 11101_household_estimation_data_2020.csv 1
# 11102_household_estimation_data_2020.csv 1
# 11103_household_estimation_data_2020.csv 1
# 11104_household_estimation_data_2020.csv 1
# 11105_household_estimation_data_2020.csv 1
# 11106_household_estimation_data_2020.csv 1
# 11107_household_estimation_data_2020.csv 1
# 11108_household_estimation_data_2020.csv 1
# 11109_household_estimation_data_2020.csv 1
# 11110_household_estimation_data_2020.csv 1
# 11201_household_estimation_data_2020.csv 1
# 11202_household_estimation_data_2020.csv 1
# 11203_household_estimation_data_2020.csv 1
# 11206_household_estimation_data_2020.csv 1
# 11207_household_estimation_data_2020.csv 1
# 11208_household_estimation_data_2020.csv 1
# 11209_household_estimation_data_2020.csv 1
# 11210_household_estimation_data_2020.csv 1
# 11211_household_estimation_data_2020.csv 1
# 11212_household_estimation_data_2020.csv 1
# 11214_household_estimation_data_2020.csv 1
# 11215_household_estimation_data_2020.csv 1
# 11216_household_estimation_data_2020.csv 1
# 11217_household_estimation_data_2020.csv 1
# 11218_household_estimation_data_2020.csv 1
# 11219_household_estimation_data_2020.csv 1
# 11221_household_estimation_data_2020.csv 1
# 11222_household_estimation_data_2020.csv 1
# 11223_household_estimation_data_2020.csv 1
# 11224_household_estimation_data_2020.csv 1
# 11225_household_estimation_data_2020.csv 1
# 11227_household_estimation_data_2020.csv 1
# 11228_household_estimation_data_2020.csv 1
# 11229_household_estimation_data_2020.csv 1
# 11230_household_estimation_data_2020.csv 1
# 11231_household_estimation_data_2020.csv 1
# 11232_household_estimation_data_2020.csv 1
# 11233_household_estimation_data_2020.csv 1
# 11234_household_estimation_data_2020.csv 1
# 11235_household_estimation_data_2020.csv 1
# 11237_household_estimation_data_2020.csv 1
# 11238_household_estimation_data_2020.csv 1
# 11239_household_estimation_data_2020.csv 1
# 11240_household_estimation_data_2020.csv 1
# 11241_household_estimation_data_2020.csv 1
# 11242_household_estimation_data_2020.csv 1
# 11243_household_estimation_data_2020.csv 1
# 11245_household_estimation_data_2020.csv 1
# 11246_household_estimation_data_2020.csv 1
# 11301_household_estimation_data_2020.csv 1
# 11324_household_estimation_data_2020.csv 1
# 11326_household_estimation_data_2020.csv 1
# 11327_household_estimation_data_2020.csv 1
# 11341_household_estimation_data_2020.csv 1
# 11342_household_estimation_data_2020.csv 1
# 11343_household_estimation_data_2020.csv 1
# 11346_household_estimation_data_2020.csv 1
# 11347_household_estimation_data_2020.csv 1
# 11348_household_estimation_data_2020.csv 1
# 11349_household_estimation_data_2020.csv 1
# 11361_household_estimation_data_2020.csv 1
# 11362_household_estimation_data_2020.csv 1
# 11363_household_estimation_data_2020.csv 1
# 11365_household_estimation_data_2020.csv 1
# 11369_household_estimation_data_2020.csv 1
# 11381_household_estimation_data_2020.csv 1
# 11383_household_estimation_data_2020.csv 1
# 11385_household_estimation_data_2020.csv 1
# 11408_household_estimation_data_2020.csv 1
# 11442_household_estimation_data_2020.csv 1
# 11464_household_estimation_data_2020.csv 1
# 11465_household_estimation_data_2020.csv 1
# 12101_household_estimation_data_2020.csv 1
# 12102_household_estimation_data_2020.csv 1
# 12103_household_estimation_data_2020.csv 1
# 12104_household_estimation_data_2020.csv 1
# 12105_household_estimation_data_2020.csv 1
# 12106_household_estimation_data_2020.csv 1
# 12202_household_estimation_data_2020.csv 1
# 12203_household_estimation_data_2020.csv 1
# 12204_household_estimation_data_2020.csv 1
# 12205_household_estimation_data_2020.csv 1
# 12206_household_estimation_data_2020.csv 1
# 12207_household_estimation_data_2020.csv 1
# 12208_household_estimation_data_2020.csv 1
# 12210_household_estimation_data_2020.csv 1
# 12211_household_estimation_data_2020.csv 1
# 12212_household_estimation_data_2020.csv 1
# 12213_household_estimation_data_2020.csv 1
# 12215_household_estimation_data_2020.csv 1
# 12216_household_estimation_data_2020.csv 1
# 12217_household_estimation_data_2020.csv 1
# 12218_household_estimation_data_2020.csv 1
# 12219_household_estimation_data_2020.csv 1
# 12220_household_estimation_data_2020.csv 1
# 12221_household_estimation_data_2020.csv 1
# 12222_household_estimation_data_2020.csv 1
# 12223_household_estimation_data_2020.csv 1
# 12224_household_estimation_data_2020.csv 1
# 12225_household_estimation_data_2020.csv 1
# 12226_household_estimation_data_2020.csv 1
# 12227_household_estimation_data_2020.csv 1
# 12228_household_estimation_data_2020.csv 1
# 12229_household_estimation_data_2020.csv 1
# 12230_household_estimation_data_2020.csv 1
# 12231_household_estimation_data_2020.csv 1
# 12232_household_estimation_data_2020.csv 1
# 12233_household_estimation_data_2020.csv 1
# 12234_household_estimation_data_2020.csv 1
# 12235_household_estimation_data_2020.csv 1
# 12236_household_estimation_data_2020.csv 1
# 12237_household_estimation_data_2020.csv 1
# 12238_household_estimation_data_2020.csv 1
# 12239_household_estimation_data_2020.csv 1
# 12322_household_estimation_data_2020.csv 1
# 12329_household_estimation_data_2020.csv 1
# 12342_household_estimation_data_2020.csv 1
# 12347_household_estimation_data_2020.csv 1
# 12349_household_estimation_data_2020.csv 1
# 12403_household_estimation_data_2020.csv 1
# 12409_household_estimation_data_2020.csv 1
# 12410_household_estimation_data_2020.csv 1
# 12421_household_estimation_data_2020.csv 1
# 12422_household_estimation_data_2020.csv 1
# 12423_household_estimation_data_2020.csv 1
# 12424_household_estimation_data_2020.csv 1
# 12426_household_estimation_data_2020.csv 1
# 12427_household_estimation_data_2020.csv 1
# 12441_household_estimation_data_2020.csv 1
# 12443_household_estimation_data_2020.csv 1
# 12463_household_estimation_data_2020.csv 1
# 13101_household_estimation_data_2020.csv 1
# 13102_household_estimation_data_2020.csv 1
# 13103_household_estimation_data_2020.csv 1
# 13104_household_estimation_data_2020.csv 1
# 13105_household_estimation_data_2020.csv 1
# 13106_household_estimation_data_2020.csv 1
# 13107_household_estimation_data_2020.csv 1
# 13108_household_estimation_data_2020.csv 1
# 13109_household_estimation_data_2020.csv 1
# 13110_household_estimation_data_2020.csv 1
# 13111_household_estimation_data_2020.csv 1
# 13112_household_estimation_data_2020.csv 1
# 13113_household_estimation_data_2020.csv 1
# 13114_household_estimation_data_2020.csv 1
# 13115_household_estimation_data_2020.csv 1
# 13116_household_estimation_data_2020.csv 1
# 13117_household_estimation_data_2020.csv 1
# 13118_household_estimation_data_2020.csv 1
