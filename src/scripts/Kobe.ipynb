# %%
import pandas as pd

# %%
suma_pop = pd.read_csv("C://Users//pybdt//Documents//Scripts/Suma_filtered4.csv", names=['hid','type', 'adddress','lon','lat','pid', 'age','gender','occupation'], skiprows=1)
suma_pop
# Out:
#                hid  type  adddress         lon        lat       pid  age  \
# 0          28107_1     2     28107  135.112741  34.647971  92137657   38
# 1          28107_1     2     28107  135.112741  34.647971  92137658    4
# 2          28107_2     3     28107  135.112477  34.647881  92137659   59
# 3          28107_2     3     28107  135.112477  34.647881  92137660   25
# 4          28107_3    16     28107  135.112534  34.648050  92137661   20
# ...            ...   ...       ...         ...        ...       ...  ...
# 20900  28107_73006     2     28107  135.126514  34.649273  92296957   24
# 20901  28107_73007     1     28107  135.127497  34.649263  92296958   72
# 20902  28107_73007     1     28107  135.127497  34.649263  92296959   66
# 20903  28107_73008     1     28107  135.126623  34.649349  92296960   69
# 20904  28107_73008     1     28107  135.126623  34.649349  92296961   69
#
#        gender  occupation
# 0           2          21
# 1           1          11
# ...

# %%
len(suma_pop[suma_pop['gender']==2])
# Out:
# 11583

# %%
suma_pop['occupation'].hist()
# Out:
# <Axes: >

# %%
len(suma_pop[suma_pop['age']<15]), len(suma_pop), len(suma_pop[suma_pop['age']>=65])
# Out:
# (2533, 20905, 5394)

# %%
activity = pd.read_csv("C:\\Data\\PseudoPFLOW\\activity_v2\\28\\filtered_activity_28107_3rd.csv", names=['pid', 'age','gender','occupation','starttime','duration', 'purpose', 'lon', 'lat', 'address'])
activity
# Out:
#             pid  age  gender  occupation  starttime  duration  purpose  \
# 0      92137657   38       2          21          0     31500        1
# 1      92137657   38       2          21      31500     18000      200
# 2      92137657   38       2          21      49500     26100        2
# 3      92137657   38       2          21      75600     10800        1
# 4      92137660   25       1          21          0     29700        1
# ...         ...  ...     ...         ...        ...       ...      ...
# 52399  92296475   16       1          14      24300     44100        3
# 52400  92296475   16       1          14      68400     18000        1
# 52401  92296476   17       2          14          0     86400        1
# 52402  92296477   12       2          13          0     25200        1
# 52403  92296477   12       2          13      25200     61200        3
#
#               lon        lat  address
# 0      135.112741  34.647971    28107
# ...

# %%
target = activity[activity['pid'].isin(suma_pop['pid'].tolist())]
target
# Out:
#             pid  age  gender  occupation  starttime  duration  purpose  \
# 0      92137657   38       2          21          0     31500        1
# 1      92137657   38       2          21      31500     18000      200
# 2      92137657   38       2          21      49500     26100        2
# 3      92137657   38       2          21      75600     10800        1
# 4      92137660   25       1          21          0     29700        1
# ...         ...  ...     ...         ...        ...       ...      ...
# 52399  92296475   16       1          14      24300     44100        3
# 52400  92296475   16       1          14      68400     18000        1
# 52401  92296476   17       2          14          0     86400        1
# 52402  92296477   12       2          13          0     25200        1
# 52403  92296477   12       2          13      25200     61200        3
#
#               lon        lat  address
# 0      135.112741  34.647971    28107
# ...

# %%
target['purpose'].value_counts()
# Out:
# purpose
# 1      30633
# 400     5633
# 2       5297
# 100     4445
# 200     4207
# 500     1965
# 3        224
# Name: count, dtype: int64

# %%
len(target['pid'].unique())
# Out:
# 16961

# %%
target.to_csv("C:\\Data\\PseudoPFLOW\\activity_v2\\28\\filtered_activity_28107_3rd.csv", index=None, header=None)

# %%
old = pd.read_csv("C:\\Data\\PseudoPFLOW\\activity_merge3\\28\\filtered_activity_28107.csv", names=['pid', 'age','gender','occupation','starttime','duration', 'purpose', 'lon', 'lat', 'address'])
old
# Out:
#             pid  age  gender  occupation  starttime  duration  purpose  \
# 0      92137657   38       2          21          0     27000        1
# 1      92137657   38       2          21      27000     45000        2
# 2      92137657   38       2          21      72000     14400        1
# 3      92137660   25       1          21          0     25200        1
# 4      92137660   25       1          21      25200     17100        2
# ...         ...  ...     ...         ...        ...       ...      ...
# 20272  92296263    9       1          12          0     86400        1
# 20273  92296264    8       2          12          0     25200        1
# 20274  92296264    8       2          12      25200     27900        3
# 20275  92296264    8       2          12      53100     25200      400
# 20276  92296264    8       2          12      78300      8100        1
#
#               lon        lat  address
# 0      135.112741  34.647971    28107
# ...

# %%
len(old.pid.unique())
# Out:
# 8607
