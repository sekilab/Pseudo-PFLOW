# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Data\PseudoPFLOW\activity_v2_test\13\activity_13101.csv", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     30600        1
# 1       33922893   59       2          21      30600      2700      100
# 2       33922893   59       2          21      33300     53100        1
# 3       33922894   33       2          21          0     26100        1
# 4       33922894   33       2          21      26100     36000        2
# ...          ...  ...     ...         ...        ...       ...      ...
# 160469  33980835   12       1          13      63900     22500        1
# 160470  33980836    9       2          12          0     27000        1
# 160471  33980836    9       2          12      27000     26100        3
# 160472  33980836    9       2          12      53100      5400      400
# 160473  33980836    9       2          12      58500     27900        1
#
#                lon        lat    zip
# 0       139.741445  35.683175  13101
# ...

# %%
df[df['occupation']<21]
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 136550  33922906    7       2          12          0     25200        1
# 136551  33922906    7       2          12      25200     36900        3
# 136552  33922906    7       2          12      62100     24300        1
# 136553  33922919    6       1          12          0     27900        1
# 136554  33922919    6       1          12      27900     27900        3
# ...          ...  ...     ...         ...        ...       ...      ...
# 160469  33980835   12       1          13      63900     22500        1
# 160470  33980836    9       2          12          0     27000        1
# 160471  33980836    9       2          12      27000     26100        3
# 160472  33980836    9       2          12      53100      5400      400
# 160473  33980836    9       2          12      58500     27900        1
#
#                lon        lat    zip
# 136550  139.739956  35.682343  13101
# ...

# %%
len(df['pid'].unique())
# Out:
# 55945

# %%
df["hour"] = df["starttime"] // 3600
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     30600        1
# 1       33922893   59       2          21      30600      2700      100
# 2       33922893   59       2          21      33300     53100        1
# 3       33922894   33       2          21          0     26100        1
# 4       33922894   33       2          21      26100     36000        2
# ...          ...  ...     ...         ...        ...       ...      ...
# 160469  33980835   12       1          13      63900     22500        1
# 160470  33980836    9       2          12          0     27000        1
# 160471  33980836    9       2          12      27000     26100        3
# 160472  33980836    9       2          12      53100      5400      400
# 160473  33980836    9       2          12      58500     27900        1
#
#                lon        lat    zip  hour
# 0       139.741445  35.683175  13101     0
# ...

# %%
df[df['purpose']==100]['hour'].hist()
# Out:
# <Axes: >

# %%
df = pd.read_csv(r"C:/Users/pybdt/Downloads/LIU_LUYAO_activity_7wards/activity_13101.csv", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     27900        1
# 1       33922893   59       2          21      27900     32400        2
# 2       33922893   59       2          21      60300     26100        1
# 3       33922894   33       2          21          0     24300        1
# 4       33922894   33       2          21      24300     27000        2
# ...          ...  ...     ...         ...        ...       ...      ...
# 160600  33980836    9       2          12          0     22500        1
# 160601  33980836    9       2          12      22500     36000        3
# 160602  33980836    9       2          12      58500     10800        1
# 160603  33980836    9       2          12      69300      5400      200
# 160604  33980836    9       2          12      74700     11700        1
#
#                lon        lat    zip
# 0       139.741445  35.683175  13101
# ...

# %%
df = pd.read_csv(r"C:/Users/pybdt/Downloads/13/activity_13101.csv", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     21600        1
# 1       33922893   59       2          21      21600     40500        2
# 2       33922893   59       2          21      62100     24300        1
# 3       33922894   33       2          21          0     27000        1
# 4       33922894   33       2          21      27000     31500        2
# ...          ...  ...     ...         ...        ...       ...      ...
# 142421  33980835   12       1          13      24300     27000        3
# 142422  33980835   12       1          13      51300     35100        1
# 142423  33980836    9       2          12          0     27000        1
# 142424  33980836    9       2          12      27000     41400        3
# 142425  33980836    9       2          12      68400     18000        1
#
#                lon        lat    zip
# 0       139.741445  35.683175  13101
# ...

# %%
df[df['occupation']<21]
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 136575  33922906    7       2          12          0     28800        1
# 136576  33922906    7       2          12      28800     22500        3
# 136577  33922906    7       2          12      51300     35100        1
# 136578  33922919    6       1          12          0     22500        1
# 136579  33922919    6       1          12      22500     37800        3
# ...          ...  ...     ...         ...        ...       ...      ...
# 142421  33980835   12       1          13      24300     27000        3
# 142422  33980835   12       1          13      51300     35100        1
# 142423  33980836    9       2          12          0     27000        1
# 142424  33980836    9       2          12      27000     41400        3
# 142425  33980836    9       2          12      68400     18000        1
#
#                lon        lat    zip
# 136575  139.739956  35.682343  13101
# ...

# %%
df["hour"] = df["starttime"] // 3600
df

# %%
df["hour"] = df["starttime"] // 3600
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     21600        1
# 1       33922893   59       2          21      21600     40500        2
# 2       33922893   59       2          21      62100     24300        1
# 3       33922894   33       2          21          0     27000        1
# 4       33922894   33       2          21      27000     31500        2
# ...          ...  ...     ...         ...        ...       ...      ...
# 142421  33980835   12       1          13      24300     27000        3
# 142422  33980835   12       1          13      51300     35100        1
# 142423  33980836    9       2          12          0     27000        1
# 142424  33980836    9       2          12      27000     41400        3
# 142425  33980836    9       2          12      68400     18000        1
#
#                lon        lat    zip  hour
# 0       139.741445  35.683175  13101     0
# ...

# %%
df[df['purpose']==100]['hour'].hist()
# Out:
# <Axes: >

# %%
len(df['pid'].unique())
# Out:
# 50338

# %%
df = pd.read_csv(r"C:/Users/pybdt/Downloads/activity_13101.csv", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33922893   59       2          21          0     53100        1
# 1       33922893   59       2          21      53100      3600      300
# 2       33922893   59       2          21      56700     29700        1
# 3       33922894   33       2          21          0     86400        1
# 4       33922895   73       1          21          0     27900        1
# ...          ...  ...     ...         ...        ...       ...      ...
# 144483  33980835   12       1          13      62100      1800      400
# 144484  33980835   12       1          13      63900     22500        1
# 144485  33980836    9       2          12          0     27900        1
# 144486  33980836    9       2          12      27900     24300        3
# 144487  33980836    9       2          12      52200     34200        1
#
#                lon        lat    zip
# 0       139.741445  35.683175  13101
# ...

# %%
df["hour"] = df["starttime"] // 3600
df[df['purpose']==100]['hour'].hist()
# Out:
# <Axes: >
