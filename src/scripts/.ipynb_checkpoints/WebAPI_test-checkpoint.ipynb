# %%
import requests
import json
import datetime
import random

import pandas as pd
import geopandas as gpd

import folium

from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# ## CreateSession

# %%
url = 'https://157.82.223.35/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)
# Out:
# Session created successfully
# 1,461AD6C8E91C
#
# Status:1, SessionID: 461AD6C8E91C
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
url = 'https://pflow-api.csis.u-tokyo.ac.jp/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fb110349880>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='pflow-api.csis.u-tokyo.ac.jp', port=443): Max retries exceeded with url: /webapi/CreateSession (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb110349880>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /var/folders/5z/f4gzbtkn3kb0xq5k22hdlj7h0000gn/T/ipykernel_75603/762521866.py in <module>
#       6 }
#       7
# ----> 8 response = requests.post(url, data=data, verify=False)
#       9
#      10 if response.status_code == 200:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='pflow-api.csis.u-tokyo.ac.jp', port=443): Max retries exceeded with url: /webapi/CreateSession (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fb110349880>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
url = 'https://157.82.223.35/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)

url = 'https://157.82.223.35/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)

# %%
headers
# Out:
# {'WebApiSessionID': '34815F80CAA1'}

# %% [markdown]
# ## Multithread Test

# %%
def call_api(url, headers, data):
    response = requests.post(url, cookies=headers, data=data, verify=False)
    if response.status_code == 200:
        values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
        if values[0].strip('\r\n') == '1':  # Assuming the first value is the status
            print("NearestRoadPoint Detected")
            print("Status: {}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(*values))
            return True
    else:
        print('Failed to post data:', response.status_code)
        return False

# %%
url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}
num_threads = 10  # Number of concurrent threads

start_time = datetime.datetime.now()

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]

    for future in as_completed(futures):
        result = future.result()
        # Handle the result if needed

end_time = datetime.datetime.now()
print("Total execution time: ", end_time - start_time)
# Out:
# Total execution time:  0:00:00.146759
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
def call_api(url, headers, data):
    response = requests.post(url, cookies=headers, data=data, verify=False)
    if response.status_code == 200:
        values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
        if values[0].strip('\r\n') == '1':  # Assuming the first value is the status
            return True
    return False

def single_thread_test(url, headers, data, num_requests):
    start_time = datetime.datetime.now()
    for _ in range(num_requests):
        call_api(url, headers, data)
    end_time = datetime.datetime.now()
    return end_time - start_time

def multi_thread_test(url, headers, data, num_threads):
    start_time = datetime.datetime.now()
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]
        for future in as_completed(futures):
            result = future.result()
    end_time = datetime.datetime.now()
    return end_time - start_time

# %%
url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}

num_requests = 1000  # Number of requests for single-thread test and also the number of threads for multi-thread test

# Single-thread test
single_thread_duration = single_thread_test(url, headers, data, num_requests)
print(f"Single-thread execution time: {single_thread_duration}")

# Multi-thread test
multi_thread_duration = multi_thread_test(url, headers, data, num_requests)
print(f"Multi-thread execution time: {multi_thread_duration}")
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5z/f4gzbtkn3kb0xq5k22hdlj7h0000gn/T/ipykernel_75603/2239537438.py in multi_thread_test(url, headers, data, num_threads)
#      19         futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]
# ---> 20         for future in as_completed(futures):
#      21             result = future.result()
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in as_completed(fs, timeout)
#     244
# --> 245             waiter.event.wait(wait_timeout)
#     246
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     580             if not signaled:
# --> 581                 signaled = self._cond.wait(timeout)
#     582             return signaled
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5z/f4gzbtkn3kb0xq5k22hdlj7h0000gn/T/ipykernel_75603/3274970834.py in <module>
#      16
#      17 # Multi-thread test
# ---> 18 multi_thread_duration = multi_thread_test(url, headers, data, num_requests)
#      19 print(f"Multi-thread execution time: {multi_thread_duration}")
#
# /var/folders/5z/f4gzbtkn3kb0xq5k22hdlj7h0000gn/T/ipykernel_75603/2239537438.py in multi_thread_test(url, headers, data, num_threads)
#      19         futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]
#      20         for future in as_completed(futures):
# ---> 21             result = future.result()
#      22     end_time = datetime.datetime.now()
#      23     return end_time - start_time
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635
#     636     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 637         self.shutdown(wait=True)
#     638         return False
#     639
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# ~/opt/anaconda3/lib/python3.9/threading.py in join(self, timeout)
#    1058
#    1059         if timeout is None:
# -> 1060             self._wait_for_tstate_lock()
#    1061         else:
#    1062             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1078
#    1079         try:
# -> 1080             if lock.acquire(block, timeout):
#    1081                 lock.release()
#    1082                 self._stop()
#
# KeyboardInterrupt:

# %%
# GetMixdRoute

url = 'http://157.82.223.35/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67734',
    'StartLatitude': '35.66274',
    'GoalLongitude': '139.74852',
    'GoalLatitude': '35.66780',
    'TransportCode': '3'
}

num_requests = 10  # Number of requests for single-thread test and also the number of threads for multi-thread test

# Single-thread test
single_thread_duration = single_thread_test(url, headers, data, num_requests)
print(f"Single-thread execution time: {single_thread_duration}")

# Multi-thread test
multi_thread_duration = multi_thread_test(url, headers, data, num_requests)
print(f"Multi-thread execution time: {multi_thread_duration}")
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Single-thread execution time: 0:00:00.686180
# Multi-thread execution time: 0:00:00.112165
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## GetNearestRoadPoint

# %%
starttime = datetime.datetime.now()

url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}

response = requests.post(url, cookies=headers, data=data)

if response.status_code == 200:
    status, roadtype, roadid, meshcode, lon, lat = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)
# Out:
# NearestRoadPoint Detected
# Status:1, RoadType: 9, RoadID: 0, MeshCode: 543906, Longitude: 139.87170630, Latitude: 36.05051814
# Get Nearest Road Point time: 0:00:00.081874

# %%
starttime = datetime.datetime.now()

url = 'https://157.82.223.35/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67737',
    'StartLatitude': '35.66446',
    'GoalLongitude': '139.70264',
    'GoalLatitude': '35.65843',
    'TransportCode': '2',
    'AppDate': '20240526',
    'AppTime': '1230'
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
# "type": "FeatureCollection",
# "status": 1,
# "num_station": 6,
# "num_point": 6,
# "fare": 460,
# "total_time": 34.0,
# "length_to_start_station": 0.0,
# "time_to_start_station": 0.0,
# "total_transport_time": 34.0,
# "length_to_end_station": 0.0,
# "time_to_end_station": 0.0,
# "features": [
# {"type": "Feature",
# "properties": {
# "id": 1,
# "transportation": null,
# "station": {
# "station_name": "駒場リサーチキャンパス",
# "route": "",
# "arrival_time": "",
# "departure_time": "1237"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67683889,35.66408611]}
# },
# {"type": "Feature",
# "properties": {
# "id": 2,
# "transportation": 3,
# "station": {
# "station_name": "東北沢駅",
# "route": "東急バス・渋５５",
# "arrival_time": "1243",
# "departure_time": "1244"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67370000,35.66583333]}
# },
# {"type": "Feature",
# "properties": {
# "id": 3,
# "transportation": 4,
# "station": {
# "station_name": "東北沢",
# "route": "徒歩",
# "arrival_time": "1246",
# "departure_time": "1254"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67299166,35.66551389]}
# },
# {"type": "Feature",
# "properties": {
# "id": 4,
# "transportation": 2,
# "station": {
# "station_name": "下北沢",
# "route": "小田急小田原線",
# "arrival_time": "1255",
# "departure_time": "1301"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.66749166,35.66131944]}
# },
# {"type": "Feature",
# "properties": {
# "id": 5,
# "transportation": 2,
# "station": {
# "station_name": "渋谷",
# "route": "京王井の頭線急行",
# "arrival_time": "1305",
# "departure_time": "1306"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.70179722,35.65851389]}
# },
# {"type": "Feature",
# "properties": {
# "id": 6,
# "transportation": 4,
# "station": {
# "station_name": "渋谷駅",
# "route": "徒歩"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.70240000,35.65842500]
# }
# }
# ]
# }

# %%
response.text
# Out:
# '1\n1,6,0,0,6,0,0\n1,駒場リサーチキャンパス,,,0831\n1,東北沢駅,東急バス・渋５５,0835,0836\n1,東北沢,徒歩,0838,0843\n1,下北沢,小田急小田原線,0844,0850\n1,渋谷,京王井の頭線急行,0854,0855\n1,渋谷駅,徒歩,0900,\n1,139.67683889,35.66408611,2\n1,139.67370000,35.66583333,2\n1,139.67299166,35.66551389,2\n1,139.66749166,35.66131944,2\n1,139.70179722,35.65851389,2\n1,139.70240000,35.65842500,2\n\r\n'

# %% [markdown]
# ### Speed test

# %%
def random_coordinates():
    """Generate random latitude and longitude within Japan's bounding box."""
    # Japan's approximate bounding box
    min_lat, max_lat = 34.5, 36.0  # North latitude
    min_lon, max_lon = 138.0, 140.0  # East longitude
    lat = random.uniform(min_lat, max_lat)
    lon = random.uniform(min_lon, max_lon)
    return lat, lon

starttime = datetime.datetime.now()

url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

for _ in range(100):

    lat, lon = random_coordinates()
    
    data = {
        'UnitTypeCode': '2',
        'PosLongitude': str(lon),
        'PosLatitude': str(lat),
        'RoadKindCode': '',
        'RoadNo': '',
    }

    response = requests.post(url, cookies=headers, data=data)

    if response.status_code == 200:
        # Split the response by ',' and then each item by '\r\n', filtering out empty values
        response_values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
    
        # Check if the response contains the expected number of values
    else:
        print('Failed to post data:', response.status_code)

endtime = datetime.datetime.now()
print("Get Nearest Road Point with 10000 times in:", endtime-starttime)
# Out:
# Get Nearest Road Point with 10000 times in: 0:00:11.829270

# %% [markdown]
# ## GetRoadRoute

# %%
starttime = datetime.datetime.now()

url = 'https://157.82.223.35/webapi/GetRoadRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67727019',
    'StartLatitude': '35.66412606',
    'GoalLongitude': '138.808493',
    'GoalLatitude': '36.017459',
    'WayLongitude': '',
    'WayLatitude': '',
    'RoadKindCode': '',
    'RoadNo': '',
    'TransportCode': '6',
    'OutputNum': '1',
}

response = requests.post(url, cookies=headers, data=data)

if response.status_code == 200:
    # print(response.text)
    # print([value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()])
    split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
    route_values = split_values[11:]

    routes = []
    current_route = None
    current_coordinates = []

    for value in route_values:
        if value.isdigit(): 
            if current_route is not None:
                routes.append((current_route, current_coordinates))
            current_route = value
            current_coordinates = []
        else:
            current_coordinates.append(value)
    if current_route is not None:
        routes.append((current_route, current_coordinates))

    # print('route:', routes)
    # status, routeno, route1_len,route2_len,route3_len, route1_no, route2_no, route3_no, route1_time, route2_time, route3_time, out_route_no, lon, lat = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]

    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)
# Out:
# NearestRoadPoint Detected
# Status:1, RoadType: 9, RoadID: 0, MeshCode: 543906, Longitude: 138.23128457993383, Latitude: 34.95429023125039
# Get Nearest Road Point time: 0:00:05.389572

# %%
import folium

route_data = {}
for route, coord_pair in routes:
    if route not in route_data:
        route_data[route] = []
    route_data[route].append(tuple(map(float, coord_pair)))


first_coord = route_data['1'][0]  
map_center = [float(first_coord[1]), float(first_coord[0])]  
routesmap = folium.Map(location=map_center, zoom_start=14)


for route, coords in route_data.items():
    for coord in coords:
        folium.Marker([float(coord[1]), float(coord[0])], tooltip=f"Route {route}").add_to(routesmap)
routesmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c857dd7970f58363a9bb89179dbf38ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c857dd7970f58363a9bb89179dbf38ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c857dd7970f58363a9bb89179dbf38ed = L.map(
#                 &quot;map_c857dd7970f58363a9bb89179dbf38ed&quot;,
#                 {
#                     center: [35.664129, 139.677325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4f54e8cc9987ed0d3afa0ea7a1c2fa9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c4f54e8cc9987ed0d3afa0ea7a1c2fa9.addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#             var marker_947c7743dbfbff56d0b623492458892e = L.marker(
#                 [35.664129, 139.677325],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_947c7743dbfbff56d0b623492458892e.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d0e7b56685a420948587321d72ee1a9 = L.marker(
#                 [35.664079, 139.676325],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_2d0e7b56685a420948587321d72ee1a9.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5f92400652aaaa82302131b2fcdb5576 = L.marker(
#                 [35.664045, 139.675662],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_5f92400652aaaa82302131b2fcdb5576.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fe47c07a48682fa2478602722e269c68 = L.marker(
#                 [35.664062, 139.675125],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_fe47c07a48682fa2478602722e269c68.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8093853d84a196679d54434b85f86172 = L.marker(
#                 [35.664162, 139.674862],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_8093853d84a196679d54434b85f86172.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88a4cea62fbcc9d9ef2b58b113431282 = L.marker(
#                 [35.66432, 139.674625],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_88a4cea62fbcc9d9ef2b58b113431282.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6f505780c921c5385ef21b43c2a4f5d8 = L.marker(
#                 [35.664595, 139.6744],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_6f505780c921c5385ef21b43c2a4f5d8.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7e1b661353c7107300c63225709be5f9 = L.marker(
#                 [35.664845, 139.67425],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_7e1b661353c7107300c63225709be5f9.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79b345e824b391b8d182a7851cafdba0 = L.marker(
#                 [35.66502, 139.674162],
#                 {}
#             ).addTo(map_c857dd7970f58363a9bb89179dbf38ed);
#
#
#             marker_79b345e824b391b8d182a7851cafdba0.bindTooltip(
#                 `&lt;div&gt;
#                      Route 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_748a19c34e8dd27732555a67e3f6f0bf = L.marker(
#                 [35.665329, 139.673987],
#                 {}
#             ).addTo(map_c857dd7970f58363a9b

# %%
# Loop 10,000 times
for _ in range(10000):
    
    orilat, orilon = random_coordinates()
    destlat, destlon = random_coordinates()
    
    data = {
        'UnitTypeCode': '2',
        'StartLongitude': str(orilon),
        'StartLatitude': str(orilat),
        'GoalLongitude': str(destlon),
        'GoalLatitude': str(destlon),
        'WayLongitude': '',
        'WayLatitude': '',
        'RoadKindCode': '',
        'RoadNo': '',
        'TransportCode': '6',
        'OutputNum': '1',
    }

    response = requests.post(url, cookies=headers, data=data)

    if response.status_code == 200:
        # Assuming response.text contains comma-separated values with newline-separated route details
        split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
        route_values = split_values[11:]  # Adjust index based on actual response structure

        routes = []
        current_route = None
        current_coordinates = []

        for value in route_values:
            if value.isdigit():
                if current_route is not None:
                    routes.append((current_route, current_coordinates))
                current_route = value
                current_coordinates = []
            else:
                current_coordinates.append(value)

        if current_route is not None:
            routes.append((current_route, current_coordinates))

        # Optional: Print routes or handle them as needed
        # print('route:', routes)
    else:
        print('Failed to post data:', response.status_code)

# Calculate and print the total time taken after the loop completes
endtime = datetime.datetime.now()
print("Total time for 10,000 requests:", endtime - starttime)
# Out:
# Total time for 10,000 requests: 0:31:47.394667

# %% [markdown]
# ## GetRailRoute

# %%
starttime = datetime.datetime.now()

url = 'https://157.82.223.35/webapi/GetRailRoute'

data = {
    'UnitTypeCode': '2',
    'GeoOptionCode': '2',
    # 'StartStation': '',
    # 'GoalStation': '',
    # 'WayStation': '',
    'StartLongitude': '139.68442655057348',
    'StartLatitude': '35.65867888608949',
    'GoalLongitude': '139.73947263836726',
    'GoalLatitude': '35.638819642998044',
    'WayLongitude': '',
    'WayLatitude': '',
    'RoadKindCode': '',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
    print([value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()])
    split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
    route_values = split_values[11:]

    routes = []
    current_route = None
    current_coordinates = []

    for value in route_values:
        if value.isdigit(): 
            if current_route is not None:
                routes.append((current_route, current_coordinates))
            current_route = value
            current_coordinates = []
        else:
            current_coordinates.append(value)
    if current_route is not None:
        routes.append((current_route, current_coordinates))

    print('route:', routes)
    # status, routeno, route1_len,route2_len,route3_len, route1_no, route2_no, route3_no, route1_time, route2_time, route3_time, out_route_no, lon, lat = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]

    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        # print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
# "type": "FeatureCollection",
# "status": 1,
# "num_route": 1,
# "num_station": 4,
# "total_time": 29,
# "fare": 440,
# "features": [
# {"type": "Feature",
# "properties": {
# "station": "駒場東大前",
# "railway": "",
# "arrival_time": "",
# "departure_time": "1651",
# "required_time": 0
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.68449166,35.65865278]}
# },
# {"type": "Feature",
# "properties": {
# "station": "渋谷",
# "railway": "京王井の頭線",
# "arrival_time": "1654",
# "departure_time": "1700",
# "required_time": 3
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.70179722,35.65851389]}
# },
# {"type": "Feature",
# "properties": {
# "station": "品川",
# "railway": "ＪＲ山手線内回り",
# "arrival_time": "1712",
# "departure_time": "1718",
# "required_time": 18
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.73874166,35.62851389]}
# },
# {"type": "Feature",
# "properties": {
# "station": "泉岳寺",
# "railway": "京急本線",
# "arrival_time": "1720",
# "departure_time": "",
# "required_time": 8
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.74001944,35.63868055]}
# }
# ]
# }
#
# ['{', '"type": "FeatureCollection"', '"status": 1', '"num_route": 1', '"num_station": 4', '"total_time": 29', '"fare": 440', '"features": [', '{"type": "Feature"', '"properties": {', '"station": "駒場東大前"', '"railway": ""', '"arrival_time": ""', '"departure_time": "1651"', '"required_time": 0', '}', '"geometry": {', '"type": "Point"', '"coordinates": [139.68449166', '35.65865278]}', '}', '{"type": "Feature"', '"properties": {', '"station": "渋谷"', '"railway": "京王井の頭線"', '"arrival_time": "1654"', '"departure_time": "1700"', '"required_time": 3', '}', '"geometry": {', '"type": "Point"', '"coordinates": [139.70179722', '35.65851389]}', '}', '{"type": "Feature"', '"properties": {', '"station": "品川"', '"railway": "ＪＲ山手線内回り"', '"arrival_time": "1712"', '"departure_time": "1718"', '"required_time": 18', '}', '"geometry": {', '"type": "Point"', '"coordinates": [139.73874166', '35.62851389]}', '}', '{"type": "Feature"', '"properties": {', '"station": "泉岳寺"', '"railway": "京急本線"', '"arrival_time": "1720"', '"departure_time": ""', '"required_time": 8', '}', '"geometry": {', '"type": "Point"', '"coordinates": [139.74001944', '35.63868055]}', '}', ']', '}']
# route: []
# NearestRoadPoint Detected
# Get Nearest Road Point time: 0:00:01.848499

# %%
import requests
import datetime

# Initialize the start time
starttime = datetime.datetime.now()

url = 'http://157.82.223.35/webapi/GetRoadRoute'

# Headers or cookies should be defined if you're using them
headers = {}  # Define your headers or cookies here

# Loop 10,000 times
for _ in range(10000):
    data = {
        'UnitTypeCode': '2',
        'StartLongitude': '139.67727019',
        'StartLatitude': '35.66412606',
        'GoalLongitude': '138.808493',
        'GoalLatitude': '36.017459',
        'WayLongitude': '',
        'WayLatitude': '',
        'RoadKindCode': '',
        'RoadNo': '',
        'TransportCode': '6',
        'OutputNum': '1',
    }

    response = requests.post(url, cookies=headers, data=data)

    if response.status_code == 200:
        # Assuming response.text contains comma-separated values with newline-separated route details
        split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
        route_values = split_values[11:]  # Adjust index based on actual response structure

        routes = []
        current_route = None
        current_coordinates = []

        for value in route_values:
            if value.isdigit():
                if current_route is not None:
                    routes.append((current_route, current_coordinates))
                current_route = value
                current_coordinates = []
            else:
                current_coordinates.append(value)

        if current_route is not None:
            routes.append((current_route, current_coordinates))

        # Optional: Print routes or handle them as needed
        # print('route:', routes)
    else:
        print('Failed to post data:', response.status_code)

# Calculate and print the total time taken after the loop completes
endtime = datetime.datetime.now()
print("Total time for 10,000 requests:", endtime - starttime)

# %% [markdown]
# ## GeoJSON Check

# %%
import geojson

# %%
path = '/Users/pang/Documents/9. CSIS関連/WebAPI開発/GetMixedRoute.geojson'

gdf = gpd.read_file(path)
gdf
# Out:
#     id  transportation                                            station  \
# 0    1               1                                               None
# 1    2               1                                               None
# 2    3               1                                               None
# 3    4               1                                               None
# 4    5               1                                               None
# 5    6               2           {'station_name': '流経大柏高校前', 'route': ''}
# 6    7               2  {'station_name': '柏の葉キャンパス駅西口', 'route': '東武バス...
# 7    8               2        {'station_name': '柏の葉キャンパス', 'route': '徒歩'}
# 8    9               2  {'station_name': '北千住', 'route': 'つくばエクスプレス区間快速'}
# 9   10               2    {'station_name': '表参道', 'route': '東京メトロ千代田線準急'}
# 10  11               2        {'station_name': '渋谷', 'route': '東京メトロ銀座線'}
# 11  12               2             {'station_name': '渋谷駅', 'route': '徒歩'}
# 12  13               2       {'station_name': '二ツ橋', 'route': '東急バス・渋５５'}
# 13  14               1                                               None
# 14  15               1                                               None
# 15  16               1                                               None
# 16  17               1                                               None
#
#                       geometry
# 0   POINT (139.93284 35.90443)
# 1   POINT (139.93156 35.90383)
# 2   POINT (139.93082 35.90466)
# 3   POINT (139.93033 35.90527)
# 4   POINT (139.93034 35.90535)
# 5   POINT (139.93034 35.90535)
# 6   POINT (139.95208 35.89379)
# 7   POINT (139.95235 35.89296)
# 8   POINT (139.80513 35.74963)
# 9   POINT (139.71249 35.66510)
# 10  POINT (139.70180 35.65851)
# 11  POINT (139.70056 35.65836)
# 12  POINT (139.68370 35.66317)
# 13  POINT (139.68370 35.66317)
# 14  POINT (139.68371 35.66320)
# 15  POINT (139.68365 35.66314)
# 16  POINT (139.68521 35.66285)

# %%
with open(path) as f:
    gj = geojson.load(f)
features = gj['features']
features
# Out:
# [{"geometry": {"coordinates": [139.932844, 35.904427], "type": "Point"}, "properties": {"id": 1, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.931557, 35.903827], "type": "Point"}, "properties": {"id": 2, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.930819, 35.90466], "type": "Point"}, "properties": {"id": 3, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.930332, 35.905268], "type": "Point"}, "properties": {"id": 4, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.930344, 35.905353], "type": "Point"}, "properties": {"id": 5, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.930344, 35.905353], "type": "Point"}, "properties": {"id": 6, "station": {"route": "", "station_name": "流経大柏高校前"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.952075, 35.893792], "type": "Point"}, "properties": {"id": 7, "station": {"route": "東武バス・西柏１０", "station_name": "柏の葉キャンパス駅西口"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.952353, 35.892958], "type": "Point"}, "properties": {"id": 8, "station": {"route": "徒歩", "station_name": "柏の葉キャンパス"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.805131, 35.749625], "type": "Point"}, "properties": {"id": 9, "station": {"route": "つくばエクスプレス区間快速", "station_name": "北千住"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.712492, 35.665097], "type": "Point"}, "properties": {"id": 10, "station": {"route": "東京メトロ千代田線準急", "station_name": "表参道"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.701797, 35.658514], "type": "Point"}, "properties": {"id": 11, "station": {"route": "東京メトロ銀座線", "station_name": "渋谷"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.700558, 35.658361], "type": "Point"}, "properties": {"id": 12, "station": {"route": "徒歩", "station_name": "渋谷駅"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.6837, 35.663169], "type": "Point"}, "properties": {"id": 13, "station": {"route": "東急バス・渋５５", "station_name": "二ツ橋"}, "transportation": 2}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.6837, 35.663169], "type": "Point"}, "properties": {"id": 14, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.683712, 35.663196], "type": "Point"}, "properties": {"id": 15, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.683649, 35.663137], "type": "Point"}, "properties": {"id": 16, "station": null, "transportation": 1}, "type": "Feature"},
#  {"geometry": {"coordinates": [139.685212, 35.662846], "type": "Point"}, "properties": {"id": 17, "station": null, "transportation": 1}, "type": "Feature"}]

# %%
gj["status"]
# Out:
# 1

# %%
map_center = gdf.geometry.iloc[0].centroid.coords[:][0][::-1]  # Using the centroid of the first geometry for centering
mymap = folium.Map(location=map_center, zoom_start=12)

# Add each line in the GeoDataFrame to the map
for idx, row in gdf.iterrows():
    # Simplify geometry for faster rendering
    # simplified_geometry = row.geometry.simplify(tolerance=0.001, preserve_topology=True)
    folium.GeoJson(row.geometry, name='geojson').add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c32eb3e4b6a675b4fb891f8ef646080 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c32eb3e4b6a675b4fb891f8ef646080&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c32eb3e4b6a675b4fb891f8ef646080 = L.map(
#                 &quot;map_1c32eb3e4b6a675b4fb891f8ef646080&quot;,
#                 {
#                     center: [35.904427, 139.932844],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5392db714e6f0db3b95e1448091cafc6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#
#
#         function geo_json_1684b2aaa261f736aff72e55ca048116_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_1684b2aaa261f736aff72e55ca048116 = L.geoJson(null, {
#                 onEachFeature: geo_json_1684b2aaa261f736aff72e55ca048116_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_1684b2aaa261f736aff72e55ca048116.addData({&quot;coordinates&quot;: [139.932844, 35.904427], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_e39a9a2a59952f1d9d1cbe7e8b8c6b98_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_e39a9a2a59952f1d9d1cbe7e8b8c6b98 = L.geoJson(null, {
#                 onEachFeature: geo_json_e39a9a2a59952f1d9d1cbe7e8b8c6b98_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_e39a9a2a59952f1d9d1cbe7e8b8c6b98.addData({&quot;coordinates&quot;: [139.931557, 35.903827], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_9b655b8c475aec8d1bfa47ccbf12c431_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_9b655b8c475aec8d1bfa47ccbf12c431 = L.geoJson(null, {
#                 onEachFeature: geo_json_9b655b8c475aec8d1bfa47ccbf12c431_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_9b655b8c475aec8d1bfa47ccbf12c431.addData({&quot;coordinates&quot;: [139.930819, 35.90466], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_d8f3b447e3f0186bef3f2e099fb59bfe_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_d8f3b447e3f0186bef3f2e099fb59bfe = L.geoJson(null, {
#                 onEachFeature: geo_json_d8f3b447e3f0186bef3f2e099fb59bfe_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_d8f3b447e3f0186bef3f2e099fb59bfe.addData({&quot;coordinates&quot;: [139.930332, 35.905268], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_a4132e3068a7ebb2074d3f27600bcce0_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_a4132e3068a7ebb2074d3f27600bcce0 = L.geoJson(null, {
#                 onEachFeature: geo_json_a4132e3068a7ebb2074d3f27600bcce0_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_a4132e3068a7ebb2074d3f27600bcce0.addData({&quot;coordinates&quot;: [139.93034444, 35.90535278], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_55a74579530ef4e9486f40ed45b86286_onEachFeature(feature, layer) {
#             layer.on({
#                 click: function(e) {
#                     map_1c32eb3e4b6a675b4fb891f8ef646080.fitBounds(e.target.getBounds());
#                 }
#             });
#         };
#         var geo_json_55a74579530ef4e9486f40ed45b86286 = L.geoJson(null, {
#                 onEachFeature: geo_json_55a74579530ef4e9486f40ed45b86286_onEachFeature,
#
#         }).addTo(map_1c32eb3e4b6a675b4fb891f8ef646080);
#             geo_json_55a74579530ef4e9486f40ed45b86286.addData({&quot;coordinates&quot;: [139.93034444, 35.90535278], &quot;type&quot;: &quot;Point&quot;});
#
#
#         function geo_json_6a9ab70fbb63b4e6b4e412c85e52b732_onEachFeature(feature, layer) {

# %%
url = 'https://157.82.223.35/webapi/GetBusRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67729225768124',
    'StartLatitude': '35.66361199679843',
    'GoalLongitude': '139.93601366419756', 
    'GoalLatitude': '35.90455222566497',
    'TransportCode': '2',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)
# Out:
# Mixed Route Search successfully
# 6021
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
url = 'https://157.82.223.35/webapi/GetRoadRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67729225768124',
    'StartLatitude': '35.66361199679843',
    'GoalLongitude': '139.93601366419756', 
    'GoalLatitude': '35.90455222566497',
    'TransportCode': '6',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Mixed Route Search successfully
# {
# "type": "FeatureCollection",
# "status": 1,
# "num_route": 1,
# "features": [
# {"type": "Feature",
# "properties": {
# "id": 1,
# "length": 46336.0,
# "num_point": 116,
# "required_time": 39.3,
# "fare": 450
# },
# "geometry": {
# "type": "LineString",
# "coordinates": [
# [139.67732500,35.66412900],[139.67766200,35.66414500],[139.67862500,35.66411200],[139.67883700,35.66409500],[139.67901200,35.66407900],[139.67952400,35.66404600],[139.67968700,35.66402900],[139.68141200,35.66349600],[139.68169900,35.66337100],[139.68193700,35.66327100],[139.68266200,35.66307100],[139.68364900,35.66313700],[139.68371200,35.66319600],[139.68442400,35.66365400],[139.68546200,35.66329600],[139.68634900,35.66298700],[139.68714900,35.66272900],[139.68744900,35.66262100],[139.68794900,35.66667000],[139.68781100,35.66882000],[139.68776100,35.66990300],[139.68776100,35.66990300],[139.68771100,35.67055300],[139.68763600,35.67345300],[139.68838600,35.68213500],[139.68827300,35.68226000],[139.68799800,35.68255200],[139.68484800,35.68623500],[139.68199800,35.68916800],[139.68174800,35.68970900],[139.68162300,35.69062600],[139.68261100,35.69590900],[139.68458500,35.71044900],[139.69245900,35.72243100],[139.69254600,35.72252300],[139.69280900,35.72280600],[139.69577100,35.72663900],[139.70197000,35.73646300],[139.70299500,35.73742100],[139.70564400,35.73993800],[139.70776900,35.74252900],[139.70824400,35.74734500],[139.71440600,35.74941200],[139.71569300,35.74922800],[139.71649300,35.74913700],[139.72194200,35.74850400],[139.72796700,35.74506300],[139.72843000,35.74505400],[139.73605400,35.75000400],[139.74036600,35.75251200],[139.74150300,35.75322900],[139.74150300,35.75322900],[139.74376500,35.75667800],[139.74676500,35.75769500],[139.74676500,35.75769500],[139.74825200,35.75862800],[139.74999000,35.75967800],[139.75951400,35.76500300],[139.76485100,35.76309500],[139.76573800,35.76237000],[139.76725100,35.76147900],[139.77088800,35.76015400],[139.77821200,35.75961200],[139.79747300,35.76215400],[139.80354700,35.76162100],[139.80996000,35.75939700],[139.81324700,35.75731400],[139.81804600,35.75409700],[139.82057100,35.75590600],[139.82057100,35.75624700],[139.82002100,35.76031300],[139.81999600,35.76066300],[139.82278300,35.77118700],[139.82400700,35.77524500],[139.82500700,35.77885300],[139.82560700,35.78142800],[139.82783200,35.79390100],[139.82770600,35.79968400],[139.83104400,35.80361600],[139.83680600,35.80684100],[139.84298000,35.81129000],[139.85169100,35.82511300],[139.85651600,35.83333700],[139.85656600,35.83337900],[139.85919100,35.83609500],[139.85972800,35.83655300],[139.85972800,35.83655300],[139.86362800,35.83943600],[139.86660200,35.84108600],[139.87175200,35.84534400],[139.87175200,35.84534400],[139.87498900,35.84971000],[139.88360000,35.86668300],[139.88417500,35.86726600],[139.89521100,35.87588100],[139.89749800,35.87696400],[139.89983600,35.87813100],[139.90134800,35.87892200],[139.91802200,35.89366900],[139.92130800,35.89659400],[139.92627000,35.90069400],[139.93190700,35.90646800],[139.93699300,35.90805200],[139.93819300,35.90766800],[139.93751800,35.90930200],[139.93593100,35.91003500],[139.93293100,35.90926800],[139.93183200,35.90686800],[139.93256900,35.90636800],[139.93358100,35.90719300],[139.93456900,35.90585200],[139.93446900,35.90576800],[139.93471900,35.90557700],[139.93488100,35.90535200],[139.93516900,35.90496900],[139.93566900,35.90498500]
# ]
# }
# }
# ]
# }

# %%
# !pip install geojson
# Out:
# Collecting geojson
#   Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.1.0

# %%
url = 'https://157.82.223.35/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67729225768124',
    'StartLatitude': '35.66361199679843',
    'GoalLongitude': '139.93601366419756', 
    'GoalLatitude': '35.90455222566497',
    'TransportCode': '3'
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)
# Out:
# /Users/pang/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host '157.82.223.35'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Mixed Route Search successfully
# {
# "type": "FeatureCollection",
# "status": 1,
# "num_station": 7,
# "num_point": 14,
# "fare": 1300,
# "total_time": 109.8,
# "length_to_start_station": 0.0,
# "time_to_start_station": 0.0,
# "total_transport_time": 108.0,
# "length_to_end_station": 911.0,
# "time_to_end_station": 1.8,
# "features": [
# {"type": "Feature",
# "properties": {
# "id": 1,
# "transportation": null,
# "station": {
# "station_name": "駒場リサーチキャンパス",
# "route": ""
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67683889,35.66408611]}
# },
# {"type": "Feature",
# "properties": {
# "id": 2,
# "transportation": 3,
# "station": {
# "station_name": "東北沢駅",
# "route": "東急バス・渋５５"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67370000,35.66583333]}
# },
# {"type": "Feature",
# "properties": {
# "id": 3,
# "transportation": 4,
# "station": {
# "station_name": "東北沢",
# "route": "徒歩"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.67299166,35.66551389]}
# },
# {"type": "Feature",
# "properties": {
# "id": 4,
# "transportation": 2,
# "station": {
# "station_name": "北千住",
# "route": "小田急小田原線"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.80513055,35.74962500]}
# },
# {"type": "Feature",
# "properties": {
# "id": 5,
# "transportation": 2,
# "station": {
# "station_name": "柏",
# "route": "ＪＲ常磐線快速"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.97096389,35.86212500]}
# },
# {"type": "Feature",
# "properties": {
# "id": 6,
# "transportation": 4,
# "station": {
# "station_name": "柏駅西口",
# "route": "徒歩"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.97052778,35.86287778]}
# },
# {"type": "Feature",
# "properties": {
# "id": 7,
# "transportation": 3,
# "station": {
# "station_name": "柏の葉公園北",
# "route": "東武バス・西柏０１"
# }
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.93814166,35.90044444]}
# },
# {"type": "Feature",
# "properties": {
# "id": 8,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.93814166,35.90044444]}
# },
# {"type": "Feature",
# "properties": {
# "id": 9,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.938981,35.900719]}
# },
# {"type": "Feature",
# "properties": {
# "id": 10,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.940943,35.902161]}
# },
# {"type": "Feature",
# "properties": {
# "id": 11,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.938756,35.903977]}
# },
# {"type": "Feature",
# "properties": {
# "id": 12,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.937819,35.904769]}
# },
# {"type": "Feature",
# "properties": {
# "id": 13,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.936781,35.905477]}
# },
# {"type": "Feature",
# "properties": {
# "id": 14,
# "transportation": 1,
# "station": null
# },
# "geometry": {
# "type": "Point",
# "coordinates": [139.935669,35.904985]
# }
# }
# ]
# }
