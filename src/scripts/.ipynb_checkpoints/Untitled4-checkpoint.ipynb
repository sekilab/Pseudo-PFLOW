# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Data\PseudoPFLOW\activity_v2_test\13\activity_13102.csv", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33980839   29       1          21          0     23400        1
# 1       33980839   29       1          21      23400     63000        2
# 2       33980840   44       1          21          0     24300        1
# 3       33980840   44       1          21      24300     42300        2
# 4       33980840   44       1          21      66600     19800        1
# ...          ...  ...     ...         ...        ...       ...      ...
# 385789  34121193    8       1          12      24300     36000        3
# 385790  34121193    8       1          12      60300     26100        1
# 385791  34121196    5       2          11          0     24300        1
# 385792  34121196    5       2          11      24300     28800        3
# 385793  34121196    5       2          11      53100     33300        1
#
#                lon        lat    zip
# 0       139.768756  35.676013  13102
# ...

# %%
df["hour"] = df["starttime"] // 3600
df
# Out:
#              pid  age  gender  occupation  starttime  duration  purpose  \
# 0       33980839   29       1          21          0     23400        1
# 1       33980839   29       1          21      23400     63000        2
# 2       33980840   44       1          21          0     24300        1
# 3       33980840   44       1          21      24300     42300        2
# 4       33980840   44       1          21      66600     19800        1
# ...          ...  ...     ...         ...        ...       ...      ...
# 385789  34121193    8       1          12      24300     36000        3
# 385790  34121193    8       1          12      60300     26100        1
# 385791  34121196    5       2          11          0     24300        1
# 385792  34121196    5       2          11      24300     28800        3
# 385793  34121196    5       2          11      53100     33300        1
#
#                lon        lat    zip  hour
# 0       139.768756  35.676013  13102     0
# ...

# %%
df[df['purpose']==100]['hour'].hist()
# Out:
# <Axes: >

# %%
df = pd.read_csv(r"C:/Users/pybdt/Downloads/LIU_LUYAO_activity_7wards/", names=['pid', 'age', 'gender', 'occupation', 'starttime', 'duration', 'purpose', 'lon', 'lat', 'zip'])
df
