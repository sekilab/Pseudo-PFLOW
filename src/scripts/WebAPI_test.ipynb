# %%
import requests
import json
import datetime
import random

import pandas as pd
# import geopandas as gpd

# import folium

# from concurrent.futures import ThreadPoolExecutor, as_completed

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## CreateSession

# %%
url = 'https://pflow-api.csis.u-tokyo.ac.jp/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    # print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)
# Out:
# Session created successfully
# Status:1, SessionID: 965DCC8C70D2

# %%
url = 'http://localhost/webapi/CreateSession'

data = {
    'UserID': 'test_user1',
    'Password': 'test_user1'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)
# Out:
# Session created successfully
# 1,309BCC0A7753
#
# Status:1, SessionID: 309BCC0A7753

# %%
url = 'https://157.82.223.35/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)

url = 'https://157.82.223.35/webapi/CreateSession'

data = {
    'UserID': 'Pang_Yanbo',
    'Password': 'Pyb-37167209'
}

response = requests.post(url, data=data, verify=False)

if response.status_code == 200:
    print('Session created successfully')
    print(response.text)
    status, sessionid = response.text.split(',')
    headers = {'WebApiSessionID': sessionid.strip('\r\n')}
    print("Status:{}, SessionID: {}".format(status, sessionid))
else:
    print('Failed to post data:', response.status_code)
# Out:
# Session created successfully
# 1,3C332214CE37
#
# Status:1, SessionID: 3C332214CE37
#
# Session created successfully
# 1,C2CBB8EDC540
#
# Status:1, SessionID: C2CBB8EDC540

# %%
headers
# Out:
# {'WebApiSessionID': 'C2CBB8EDC540'}

# %% [markdown]
# ## Multithread Test

# %%
def call_api(url, headers, data):
    response = requests.post(url, cookies=headers, data=data, verify=False)
    if response.status_code == 200:
        values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
        if values[0].strip('\r\n') == '1':  # Assuming the first value is the status
            print("NearestRoadPoint Detected")
            print("Status: {}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(*values))
            return True
    else:
        print('Failed to post data:', response.status_code)
        return False

# %%
url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}
num_threads = 10  # Number of concurrent threads

start_time = datetime.datetime.now()

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]

    for future in as_completed(futures):
        result = future.result()
        # Handle the result if needed

end_time = datetime.datetime.now()
print("Total execution time: ", end_time - start_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 14
#      10 num_threads = 10  # Number of concurrent threads
#      12 start_time = datetime.datetime.now()
# ---> 14 with ThreadPoolExecutor(max_workers=num_threads) as executor:
#      15     futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]
#      17     for future in as_completed(futures):
#
# NameError: name 'ThreadPoolExecutor' is not defined

# %%
def call_api(url, headers, data):
    response = requests.post(url, cookies=headers, data=data, verify=False)
    if response.status_code == 200:
        values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
        if values[0].strip('\r\n') == '1':  # Assuming the first value is the status
            return True
    return False

def single_thread_test(url, headers, data, num_requests):
    start_time = datetime.datetime.now()
    for _ in range(num_requests):
        call_api(url, headers, data)
    end_time = datetime.datetime.now()
    return end_time - start_time

def multi_thread_test(url, headers, data, num_threads):
    start_time = datetime.datetime.now()
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = [executor.submit(call_api, url, headers, data) for _ in range(num_threads)]
        for future in as_completed(futures):
            result = future.result()
    end_time = datetime.datetime.now()
    return end_time - start_time

# %%
url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}

num_requests = 1000  # Number of requests for single-thread test and also the number of threads for multi-thread test

# Single-thread test
single_thread_duration = single_thread_test(url, headers, data, num_requests)
print(f"Single-thread execution time: {single_thread_duration}")

# Multi-thread test
multi_thread_duration = multi_thread_test(url, headers, data, num_requests)
print(f"Multi-thread execution time: {multi_thread_duration}")

# %%
# GetMixdRoute

url = 'http://157.82.223.35/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67734',
    'StartLatitude': '35.66274',
    'GoalLongitude': '139.74852',
    'GoalLatitude': '35.66780',
    'AppDate': '20240401',
    'AppTime': '0845',
    'TransportCode': '3'
}

num_requests = 30  # Number of requests for single-thread test and also the number of threads for multi-thread test

# Single-thread test
single_thread_duration = single_thread_test(url, headers, data, num_requests)
print(f"Single-thread execution time: {single_thread_duration}")

# Multi-thread test
multi_thread_duration = multi_thread_test(url, headers, data, num_requests)
print(f"Multi-thread execution time: {multi_thread_duration}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 19
#      16 num_requests = 30  # Number of requests for single-thread test and also the number of threads for multi-thread test
#      18 # Single-thread test
# ---> 19 single_thread_duration = single_thread_test(url, headers, data, num_requests)
#      20 print(f"Single-thread execution time: {single_thread_duration}")
#      22 # Multi-thread test
#
# NameError: name 'single_thread_test' is not defined

# %% [markdown]
# ## GetNearestRoadPoint

# %%
starttime = datetime.datetime.now()

url = 'http://localhost/webapi/GetNearestRoadPoint'

data = {
    'UnitTypeCode': '2',
    'PosLongitude': '139.8732',
    'PosLatitude': '36.0484',
    'RoadKindCode': '',
    'RoadNo': '',
}

response = requests.post(url, cookies=headers, data=data)

if response.status_code == 200:
    status, roadtype, roadid, meshcode, lon, lat = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)

# %%
starttime = datetime.datetime.now()

url = 'http://localhost/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67737',
    'StartLatitude': '35.66446',
    'GoalLongitude': '139.70264',
    'GoalLatitude': '35.65843',
    'TransportCode': '2',
    'AppDate': '20240526',
    'AppTime': '1230'
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)

# %%
response.text

# %% [markdown]
# ### Speed test

# %%
def random_coordinates():
    """Generate random latitude and longitude within Japan's bounding box."""
    # Japan's approximate bounding box
    min_lat, max_lat = 34.5, 36.0  # North latitude
    min_lon, max_lon = 138.0, 140.0  # East longitude
    lat = random.uniform(min_lat, max_lat)
    lon = random.uniform(min_lon, max_lon)
    return lat, lon

starttime = datetime.datetime.now()

url = 'http://157.82.223.35/webapi/GetNearestRoadPoint'

for _ in range(100):

    lat, lon = random_coordinates()
    
    data = {
        'UnitTypeCode': '2',
        'PosLongitude': str(lon),
        'PosLatitude': str(lat),
        'RoadKindCode': '',
        'RoadNo': '',
    }

    response = requests.post(url, cookies=headers, data=data, verify=False)

    if response.status_code == 200:
        # Split the response by ',' and then each item by '\r\n', filtering out empty values
        response_values = [value for s in response.text.split(',') for value in s.split('\r\n') if value]
    
        # Check if the response contains the expected number of values
    else:
        print('Failed to post data:', response.status_code)

endtime = datetime.datetime.now()
print("Get Nearest Road Point with 10000 times in:", endtime-starttime)

# %% [markdown]
# ## GetRoadRoute

# %%
starttime = datetime.datetime.now()

url = 'https://157.82.223.35/webapi/GetRoadRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': 139.67727019,
    'StartLatitude': 35.66412606,
    'GoalLongitude': 138.808493,
    'GoalLatitude': 36.017459,
    'WayLongitude': '',
    'WayLatitude': '',
    'RoadKindCode': '',
    'RoadNo': '',
    'TransportCode': '6',
    'OutputNum': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
    # print([value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()])
    split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
    route_values = split_values[11:]

    routes = []
    current_route = None
    current_coordinates = []

    for value in route_values:
        if value.isdigit(): 
            if current_route is not None:
                routes.append((current_route, current_coordinates))
            current_route = value
            current_coordinates = []
        else:
            current_coordinates.append(value)
    if current_route is not None:
        routes.append((current_route, current_coordinates))

    # print('route:', routes)
    # status, routeno, route1_len,route2_len,route3_len, route1_no, route2_no, route3_no, route1_time, route2_time, route3_time, out_route_no, lon, lat = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]

    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        # print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)

# %%
import folium

route_data = {}
for route, coord_pair in routes:
    if route not in route_data:
        route_data[route] = []
    route_data[route].append(tuple(map(float, coord_pair)))


first_coord = route_data['1'][0]  
map_center = [float(first_coord[1]), float(first_coord[0])]  
routesmap = folium.Map(location=map_center, zoom_start=14)


for route, coords in route_data.items():
    for coord in coords:
        folium.Marker([float(coord[1]), float(coord[0])], tooltip=f"Route {route}").add_to(routesmap)
routesmap

# %%
# Loop 10,000 times
for _ in range(10000):
    
    orilat, orilon = random_coordinates()
    destlat, destlon = random_coordinates()
    
    data = {
        'UnitTypeCode': '2',
        'StartLongitude': str(orilon),
        'StartLatitude': str(orilat),
        'GoalLongitude': str(destlon),
        'GoalLatitude': str(destlon),
        'WayLongitude': '',
        'WayLatitude': '',
        'RoadKindCode': '',
        'RoadNo': '',
        'TransportCode': '6',
        'OutputNum': '1',
    }

    response = requests.post(url, cookies=headers, data=data)

    if response.status_code == 200:
        # Assuming response.text contains comma-separated values with newline-separated route details
        split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
        route_values = split_values[11:]  # Adjust index based on actual response structure

        routes = []
        current_route = None
        current_coordinates = []

        for value in route_values:
            if value.isdigit():
                if current_route is not None:
                    routes.append((current_route, current_coordinates))
                current_route = value
                current_coordinates = []
            else:
                current_coordinates.append(value)

        if current_route is not None:
            routes.append((current_route, current_coordinates))

        # Optional: Print routes or handle them as needed
        # print('route:', routes)
    else:
        print('Failed to post data:', response.status_code)

# Calculate and print the total time taken after the loop completes
endtime = datetime.datetime.now()
print("Total time for 10,000 requests:", endtime - starttime)

# %% [markdown]
# ## GetRailRoute

# %%
starttime = datetime.datetime.now()

url = 'https://157.82.223.35/webapi/GetRailRoute'

data = {
    'UnitTypeCode': '2',
    'GeoOptionCode': '2',
    # 'StartStation': '',
    # 'GoalStation': '',
    # 'WayStation': '',
    'StartLongitude': '139.68442655057348',
    'StartLatitude': '35.65867888608949',
    'GoalLongitude': '139.73947263836726',
    'GoalLatitude': '35.638819642998044',
    'WayLongitude': '',
    'WayLatitude': '',
    'RoadKindCode': '',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
    print([value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()])
    split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
    route_values = split_values[11:]

    routes = []
    current_route = None
    current_coordinates = []

    for value in route_values:
        if value.isdigit(): 
            if current_route is not None:
                routes.append((current_route, current_coordinates))
            current_route = value
            current_coordinates = []
        else:
            current_coordinates.append(value)
    if current_route is not None:
        routes.append((current_route, current_coordinates))

    print('route:', routes)
    # status, routeno, route1_len,route2_len,route3_len, route1_no, route2_no, route3_no, route1_time, route2_time, route3_time, out_route_no, lon, lat = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]

    if status.strip('\r\n') == '1':
        print("NearestRoadPoint Detected")
        # print("Status:{}, RoadType: {}, RoadID: {}, MeshCode: {}, Longitude: {}, Latitude: {}".format(status, roadtype, roadid, meshcode, lon, lat))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)

# %%
import requests
import datetime

# Initialize the start time
starttime = datetime.datetime.now()

url = 'http://157.82.223.35/webapi/GetRoadRoute'

# Headers or cookies should be defined if you're using them
headers = {}  # Define your headers or cookies here

# Loop 10,000 times
for _ in range(10000):
    data = {
        'UnitTypeCode': '2',
        'StartLongitude': '139.67727019',
        'StartLatitude': '35.66412606',
        'GoalLongitude': '138.808493',
        'GoalLatitude': '36.017459',
        'WayLongitude': '',
        'WayLatitude': '',
        'RoadKindCode': '',
        'RoadNo': '',
        'TransportCode': '6',
        'OutputNum': '1',
    }

    response = requests.post(url, cookies=headers, data=data)

    if response.status_code == 200:
        # Assuming response.text contains comma-separated values with newline-separated route details
        split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
        route_values = split_values[11:]  # Adjust index based on actual response structure

        routes = []
        current_route = None
        current_coordinates = []

        for value in route_values:
            if value.isdigit():
                if current_route is not None:
                    routes.append((current_route, current_coordinates))
                current_route = value
                current_coordinates = []
            else:
                current_coordinates.append(value)

        if current_route is not None:
            routes.append((current_route, current_coordinates))

        # Optional: Print routes or handle them as needed
        # print('route:', routes)
    else:
        print('Failed to post data:', response.status_code)

# Calculate and print the total time taken after the loop completes
endtime = datetime.datetime.now()
print("Total time for 10,000 requests:", endtime - starttime)

# %% [markdown]
# ## GeoJSON Check

# %%
import geojson

# %%
path = '/Users/pang/Documents/9. CSIS関連/WebAPI開発/GetMixedRoute.geojson'

gdf = gpd.read_file(path)
gdf

# %%
with open(path) as f:
    gj = geojson.load(f)
features = gj['features']
features

# %%
gj["status"]

# %%
map_center = gdf.geometry.iloc[0].centroid.coords[:][0][::-1]  # Using the centroid of the first geometry for centering
mymap = folium.Map(location=map_center, zoom_start=12)

# Add each line in the GeoDataFrame to the map
for idx, row in gdf.iterrows():
    # Simplify geometry for faster rendering
    # simplified_geometry = row.geometry.simplify(tolerance=0.001, preserve_topology=True)
    folium.GeoJson(row.geometry, name='geojson').add_to(mymap)

mymap

# %%
url = 'https://157.82.223.35/webapi/GetBusRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67729225768124',
    'StartLatitude': '35.66361199679843',
    'GoalLongitude': '139.93601366419756', 
    'GoalLatitude': '35.90455222566497',
    'TransportCode': '2',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)

# %%
url = 'https://157.82.223.35/webapi/GetRoadRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67729225768124',
    'StartLatitude': '35.66361199679843',
    'GoalLongitude': '139.93601366419756', 
    'GoalLatitude': '35.90455222566497',
    'TransportCode': '6',
    'AppDate': '20231124',
    'AppTime': '1645',
    'StartGoalType': '1',
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)

# %%
# !pip install geojson

# %%
url = 'https://pflow-api.csis.u-tokyo.ac.jp/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '135.11522505137435',
    'StartLatitude': '34.70782059894499',
    'GoalLongitude': '135.0944824541985', 
    'GoalLatitude': '34.67951081992425',
    'AppDate': '20231124',
    'AppTime': '1645',
    'TransportCode': '3',
    'MaxRoutes': 9,
    'MaxRadius': 1000
}


response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print('Mixed Route Search successfully')
    print(response.text)
else:
    print('Failed to post data:', response.status_code)
# Out:
# Mixed Route Search successfully
# {"type":"FeatureCollection","status":1,"num_station":11,"num_point":17,"fare":260,"total_time":32.0,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":31.0,"length_to_end_station":498.0,"time_to_end_station":1.0,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1659"}},"geometry":{"type":"Point","coordinates":[135.1158,34.70878056]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"テニスコート前","route":"神戸市営バス・１２０系統","arrival_time":"1700","departure_time":"1700"}},"geometry":{"type":"Point","coordinates":[135.11604722,34.71223056]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"星和台南","route":"神戸市営バス・１２０系統","arrival_time":"1702","departure_time":"1702"}},"geometry":{"type":"Point","coordinates":[135.12153611,34.71548889]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"市民防災総合センター","route":"神戸市営バス・１２０系統","arrival_time":"1703","departure_time":"1703"}},"geometry":{"type":"Point","coordinates":[135.12086389,34.70911111]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり北町","route":"神戸市営バス・１２０系統","arrival_time":"1704","departure_time":"1704"}},"geometry":{"type":"Point","coordinates":[135.12114167,34.70633333]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台","route":"神戸市営バス・１２０系統","arrival_time":"1708","departure_time":"1708"}},"geometry":{"type":"Point","coordinates":[135.12357778,34.70038611]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"神戸市営バス・１２０系統","arrival_time":"1709","departure_time":"1709"}},"geometry":{"type":"Point","coordinates":[135.12110833,34.69766944]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"神戸市営バス・１２０系統","arrival_time":"1710","departure_time":"1710"}},"geometry":{"type":"Point","coordinates":[135.12471945,34.69548889]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"落合団地前","route":"神戸市営バス・１２０系統","arrival_time":"1716","departure_time":"1716"}},"geometry":{"type":"Point","coordinates":[135.09868611,34.68604444]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"名谷駅前","route":"神戸市営バス・１２０系統","arrival_time":"1726","departure_time":"1727"}},"geometry":{"type":"Point","coordinates":[135.09305278,34.6791]}},{"type":"Feature","properties":{"id":11,"transportation":4,"station":{"station_name":"名谷","route":"徒歩","arrival_time":"1730","departure_time":""}},"geometry":{"type":"Point","coordinates":[135.09463333,34.67930833]}},{"type":"Feature","properties":{"id":12,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.09463333,34.67930833]}},{"type":"Feature","properties":{"id":13,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.095363,34.679916]}},{"type":"Feature","properties":{"id":14,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.096875,34.679616]}},{"type":"Feature","properties":{"id":15,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.09655,34.680482]}},{"type":"Feature","properties":{"id":16,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.0952,34.680266]}},{"type":"Feature","properties":{"id":17,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.093875,34.680074]}}]}
# {"type":"FeatureCollection","status":1,"num_station":12,"num_point":15,"fare":260,"total_time":33.5,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":33.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1659"}},"geometry":{"type":"Point","coordinates":[135.1158,34.70878056]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"テニスコート前","route":"神戸市営バス・１２０系統","arrival_time":"1700","departure_time":"1700"}},"geometry":{"type":"Point","coordinates":[135.11604722,34.71223056]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"星和台南","route":"神戸市営バス・１２０系統","arrival_time":"1702","departure_time":"1702"}},"geometry":{"type":"Point","coordinates":[135.12153611,34.71548889]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"市民防災総合センター","route":"神戸市営バス・１２０系統","arrival_time":"1703","departure_time":"1703"}},"geometry":{"type":"Point","coordinates":[135.12086389,34.70911111]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり北町","route":"神戸市営バス・１２０系統","arrival_time":"1704","departure_time":"1704"}},"geometry":{"type":"Point","coordinates":[135.12114167,34.70633333]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台","route":"神戸市営バス・１２０系統","arrival_time":"1708","departure_time":"1708"}},"geometry":{"type":"Point","coordinates":[135.12357778,34.70038611]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"神戸市営バス・１２０系統","arrival_time":"1709","departure_time":"1709"}},"geometry":{"type":"Point","coordinates":[135.12110833,34.69766944]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"神戸市営バス・１２０系統","arrival_time":"1710","departure_time":"1710"}},"geometry":{"type":"Point","coordinates":[135.12471945,34.69548889]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"落合団地前","route":"神戸市営バス・１２０系統","arrival_time":"1716","departure_time":"1716"}},"geometry":{"type":"Point","coordinates":[135.09868611,34.68604444]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"名谷駅前","route":"神戸市営バス・１２０系統","arrival_time":"1726","departure_time":"1727"}},"geometry":{"type":"Point","coordinates":[135.09305278,34.6791]}},{"type":"Feature","properties":{"id":11,"transportation":4,"station":{"station_name":"名谷","route":"徒歩","arrival_time":"1730","departure_time":"1727"}},"geometry":{"type":"Point","coordinates":[135.09463333,34.67930833]}},{"type":"Feature","properties":{"id":12,"transportation":4,"station":{"station_name":"名谷駅","route":"徒歩","arrival_time":"1732","departure_time":""}},"geometry":{"type":"Point","coordinates":[135.09329722,34.67894444]}},{"type":"Feature","properties":{"id":13,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.09329722,34.67894444]}},{"type":"Feature","properties":{"id":14,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.092375,34.678974]}},{"type":"Feature","properties":{"id":15,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.093875,34.680074]}}]}
# {"type":"FeatureCollection","status":1,"num_station":12,"num_point":15,"fare":260,"total_time":34.5,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":34.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1659"}},"geometry":{"type":"Point","coordinates":[135.1158,34.70878056]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"テニスコート前","route":"神戸市営バス・１２０系統","arrival_time":"1700","departure_time":"1700"}},"geometry":{"type":"Point","coordinates":[135.11604722,34.71223056]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"星和台南","route":"神戸市営バス・１２０系統","arrival_time":"1702","departure_time":"1702"}},"geometry":{"type":"Point","coordinates":[135.12153611,34.71548889]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"市民防災総合センター","route":"神戸市営バス・１２０系統","arrival_time":"1703","departure_time":"1703"}},"geometry":{"type":"Point","coordinates":[135.12086389,34.70911111]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり北町","route":"神戸市営バス・１２０系統","arrival_time":"1704","departure_time":"1704"}},"geometry":{"type":"Point","coordinates":[135.12114167,34.70633333]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台","route":"神戸市営バス・１２０系統","arrival_time":"1708","departure_time":"1708"}},"geometry":{"type":"Point","coordinates":[135.12357778,34.70038611]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"神戸市営バス・１２０系統","arrival_time":"1709","departure_time":"1709"}},"geometry":{"type":"Point","coordinates":[135.12110833,34.69766944]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"神戸市営バス・１２０系統","arrival_time":"1710","departure_time":"1710"}},"geometry":{"type":"Point","coordinates":[135.12471945,34.69548889]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"落合団地前","route":"神戸市営バス・１２０系統","arrival_time":"1716","departure_time":"1716"}},"geometry":{"type":"Point","coordinates":[135.09868611,34.68604444]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"名谷駅前","route":"神戸市営バス・１２０系統","arrival_time":"1726","departure_time":"1727"}},"geometry":{"type":"Point","coordinates":[135.09305278,34.6791]}},{"type":"Feature","properties":{"id":11,"transportation":4,"station":{"station_name":"名谷","route":"徒歩","arrival_time":"1730","departure_time":"1727"}},"geometry":{"type":"Point","coordinates":[135.09463333,34.67930833]}},{"type":"Feature","properties":{"id":12,"transportation":4,"station":{"station_name":"名谷駅","route":"徒歩","arrival_time":"1733","departure_time":""}},"geometry":{"type":"Point","coordinates":[135.09343611,34.67891389]}},{"type":"Feature","properties":{"id":13,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.09343611,34.67891389]}},{"type":"Feature","properties":{"id":14,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.092375,34.678974]}},{"type":"Feature","properties":{"id":15,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.093875,34.680074]}}]}
# {"type":"FeatureCollection","status":1,"num_station":22,"num_point":32,"fare":540,"total_time":46.3,"length_to_start_station":1141.0,"time_to_start_station":2.3,"total_transport_time":43.0,"length_to_end_station":498.0,"time_to_end_station":1.0,"features":[{"type":"Feature","properties":{"id":1,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113173,34.707321]}},{"type":"Feature","properties":{"id":2,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113798,34.70208]}},{"type":"Feature","properties":{"id":3,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.116223,34.705613]}},{"type":"Feature","properties":{"id":4,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":5,"transportation":1,"station":{"station_name":"病院前","route":"","arrival_time":"","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":17,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":18,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_ti ...
# {"type":"FeatureCollection","status":1,"num_station":23,"num_point":29,"fare":540,"total_time":47.0,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":46.0,"length_to_end_station":498.0,"time_to_end_station":1.0,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1725"}},"geometry":{"type":"Point","coordinates":[135.1158,34.708225]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"病院前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1728","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_time":"1751"}},"geometry":{"type":"Point","coordinates":[135.16385556,34.68125833]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"湊川公園西口","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1752","departure_time":"1752"}},"geometry":{"type":"Point","coordinates":[135.166675,34.67883611]}},{"type":"Feature", ...
# {"type":"FeatureCollection","status":1,"num_station":23,"num_point":30,"fare":540,"total_time":48.8,"length_to_start_station":1141.0,"time_to_start_station":2.3,"total_transport_time":46.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113173,34.707321]}},{"type":"Feature","properties":{"id":2,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113798,34.70208]}},{"type":"Feature","properties":{"id":3,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.116223,34.705613]}},{"type":"Feature","properties":{"id":4,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":5,"transportation":1,"station":{"station_name":"病院前","route":"","arrival_time":"","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":17,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":18,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_ti ...
# {"type":"FeatureCollection","status":1,"num_station":24,"num_point":27,"fare":540,"total_time":49.5,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":49.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1725"}},"geometry":{"type":"Point","coordinates":[135.1158,34.708225]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"病院前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1728","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_time":"1751"}},"geometry":{"type":"Point","coordinates":[135.16385556,34.68125833]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"湊川公園西口","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1752","departure_time":"1752"}},"geometry":{"type":"Point","coordinates":[135.166675,34.67883611]}},{"type":"Feature", ...
# {"type":"FeatureCollection","status":1,"num_station":23,"num_point":30,"fare":540,"total_time":49.8,"length_to_start_station":1141.0,"time_to_start_station":2.3,"total_transport_time":47.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113173,34.707321]}},{"type":"Feature","properties":{"id":2,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.113798,34.70208]}},{"type":"Feature","properties":{"id":3,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.116223,34.705613]}},{"type":"Feature","properties":{"id":4,"transportation":1,"station":null},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":5,"transportation":1,"station":{"station_name":"病院前","route":"","arrival_time":"","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":17,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":18,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_ti ...
# {"type":"FeatureCollection","status":1,"num_station":24,"num_point":27,"fare":540,"total_time":50.5,"length_to_start_station":0.0,"time_to_start_station":0.0,"total_transport_time":50.0,"length_to_end_station":247.0,"time_to_end_station":0.5,"features":[{"type":"Feature","properties":{"id":1,"transportation":null,"station":{"station_name":"しあわせの村中央","route":"","arrival_time":"","departure_time":"1725"}},"geometry":{"type":"Point","coordinates":[135.1158,34.708225]}},{"type":"Feature","properties":{"id":2,"transportation":3,"station":{"station_name":"病院前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1728","departure_time":"1728"}},"geometry":{"type":"Point","coordinates":[135.11560556,34.70650278]}},{"type":"Feature","properties":{"id":3,"transportation":3,"station":{"station_name":"シルバーカレッジ前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1729","departure_time":"1729"}},"geometry":{"type":"Point","coordinates":[135.11705,34.70228056]}},{"type":"Feature","properties":{"id":4,"transportation":3,"station":{"station_name":"ひよどり台５丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1730","departure_time":"1730"}},"geometry":{"type":"Point","coordinates":[135.12066111,34.70205833]}},{"type":"Feature","properties":{"id":5,"transportation":3,"station":{"station_name":"ひよどり台","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1735","departure_time":"1735"}},"geometry":{"type":"Point","coordinates":[135.12371667,34.70043056]}},{"type":"Feature","properties":{"id":6,"transportation":3,"station":{"station_name":"ひよどり台センター前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1736","departure_time":"1736"}},"geometry":{"type":"Point","coordinates":[135.12123056,34.69789167]}},{"type":"Feature","properties":{"id":7,"transportation":3,"station":{"station_name":"ひよどり台１丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1737","departure_time":"1737"}},"geometry":{"type":"Point","coordinates":[135.12447222,34.69575278]}},{"type":"Feature","properties":{"id":8,"transportation":3,"station":{"station_name":"鵯越駅前","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1742","departure_time":"1742"}},"geometry":{"type":"Point","coordinates":[135.14105,34.691975]}},{"type":"Feature","properties":{"id":9,"transportation":3,"station":{"station_name":"滝山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1743","departure_time":"1743"}},"geometry":{"type":"Point","coordinates":[135.15116111,34.68533611]}},{"type":"Feature","properties":{"id":10,"transportation":3,"station":{"station_name":"菊水町１０丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1746","departure_time":"1746"}},"geometry":{"type":"Point","coordinates":[135.15485556,34.68141944]}},{"type":"Feature","properties":{"id":11,"transportation":3,"station":{"station_name":"鵯越町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1747","departure_time":"1747"}},"geometry":{"type":"Point","coordinates":[135.15568889,34.683725]}},{"type":"Feature","properties":{"id":12,"transportation":3,"station":{"station_name":"夢野町３丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1748","departure_time":"1748"}},"geometry":{"type":"Point","coordinates":[135.15731389,34.68489167]}},{"type":"Feature","properties":{"id":13,"transportation":3,"station":{"station_name":"夢野町２丁目","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1749","departure_time":"1749"}},"geometry":{"type":"Point","coordinates":[135.15968889,34.68535]}},{"type":"Feature","properties":{"id":14,"transportation":3,"station":{"station_name":"熊野橋","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1750","departure_time":"1750"}},"geometry":{"type":"Point","coordinates":[135.16232778,34.68239167]}},{"type":"Feature","properties":{"id":15,"transportation":3,"station":{"station_name":"東山町","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1751","departure_time":"1751"}},"geometry":{"type":"Point","coordinates":[135.16385556,34.68125833]}},{"type":"Feature","properties":{"id":16,"transportation":3,"station":{"station_name":"湊川公園西口","route":"阪急バス・西鈴神戸線１５０","arrival_time":"1752","departure_time":"1752"}},"geometry":{"type":"Point","coordinates":[135.166675,34.67883611]}},{"type":"Feature", ...

# %% [markdown]
# ## Spatial Temporal Interpolation

# %%
url = 'http://localhost/webapi/GetSTInterpolatedPoints'

data = {
    'UnitTypeCode': '1',
    'Resolution': '60',
    'DrStart': '20240411080000',
    'DrEnd': '20240411083000',
    'StartLongitude': '1396773.7',
    'StartLatitude': '356644.6',
    'GoalLongitude': '1397026.4',
    'GoalLatitude': '356584.3',
}

starttime = datetime.datetime.now()

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
    print([value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()])
    split_values = [value.strip() for s in response.text.split(',') for value in s.split('\n') if value.strip()]
    route_values = split_values[11:]

    routes = []
    current_route = None
    current_coordinates = []

    for value in route_values:
        if value.isdigit(): 
            if current_route is not None:
                routes.append((current_route, current_coordinates))
            current_route = value
            current_coordinates = []
        else:
            current_coordinates.append(value)
    if current_route is not None:
        routes.append((current_route, current_coordinates))
else:
    print('Failed to post data:', response.status_code)
    
endtime = datetime.datetime.now()
print("Get Nearest Road Point time:", endtime-starttime)
# Out:
# 20103
#
# ['20103']
# Get Nearest Road Point time: 0:00:00.003938

# %%
url = 'http://157.82.223.35/webapi/GetMixedRoute'

data = {
    'UnitTypeCode': '2',
    'StartLongitude': '139.67734',
    'StartLatitude': '35.66274',
    'GoalLongitude': '139.74852',
    'GoalLatitude': '35.66780',
    'AppDate': '20240401',
    'AppTime': '0845',
    'TransportCode': '1'
}

response = requests.post(url, cookies=headers, data=data, verify=False)

if response.status_code == 200:
    print(response.text)
# Out:
# 11018
